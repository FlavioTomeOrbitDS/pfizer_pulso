# %%
import requests
import pandas as pd
import requests
import time
import pandas as pd
import pymysql
from sqlalchemy import create_engine




df=pd.DataFrame()

DRATTR=["amiloidose","amiloidose","Vyndaqel","Vyndamax","Onpattro","patisirana","Tegsedi","inotersena","vutrisirana","PAF Polineuropatia Amiloidótica Familiar",
        "polineuropatia amiloidótica familiar","amiloidose cardíaca","ATTR","insuficiência cardíaca","ICFEp","QSART","Sudoscan",
        "Protocolo Insuficiência Cardíaca","wATTR","hATTR","síndrome túnel do carpo","Amiloidose associada à transtirretina",
        "Hipertrofia ventricular","Cardiomiopatia ","ATTR-CM","ATTR-PN","Cardiomiopatia amiloide","Cardiomiopatia amiloidótica por transtirretina",
        "CAF Cardiomiopatia Amiloidotica Familiar","Cardiomiopatia amiloide familiar","ATTRwt","ATTRh","ATTRm","ATTRv","Val30Met","Val50Met","V30M",
        "V50M","Val122Ile","Val142Ile","V122I","V142I","Cardiomiopatia restritiva","Fração de ejeção preservada","ATTR selvagem","ATTR hereditária",
        "Mutações TTR","Acoramidis","AG-10","Estabilizador TTR","Silenciador gênico TTR","ABPAR","Sequenciamento TTR","Teste genético ATTR",
        "sintomas e sinais PAF","sintomas e sinas ATTR-CM","doença hereditária"]

for i in DRATTR:
    #EXTRAIR METADADOS NOTICIAS 
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q":i,"lang":"pt","countries":"BR"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
            }
        
        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers, params=querystring).json()

        
        if response['articles']!=[]:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)
            
        else:
            df2=pd.DataFrame()
            df2[["id","title","link","published","sub_articles","source"]] = pd.DataFrame([["", "", "","","",""]])
            
            
        df2.insert(0,'company', i)
        df=pd.concat([df,df2], ignore_index=True, sort=False)
    
    
        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
            }
    except:
        pass

DRATTR_result=df
DRATTR_result=df
DRATTR_result=DRATTR_result.rename(columns={'company':'kw'})
DRATTR_result['categoria'] = 'ATTR'



df=pd.DataFrame()



df=pd.DataFrame()

Vacinas=["CRIE vacina","Campanha de vacinação -cachorros -cachorro -cães -cão -PET","Doença pneumocócica vacina","Doença meningocócica vacina","Doença meningocócica vacina",
         "Covid vacina","VPC13","Pneumonia pneumocócica","Vacina pneumonia","Vacina meningite ","Onde vacinar ",
         "Encaminhamento do paciente de risco vacinação","CTAI vacinação","Conasems vacinação","Conass vacinação","Ministério da saúde vacinação",
         "Clínica de vacinação Nimenrix ","meningite meningocócica vacina","ACWY vacina","Meningite C vacina","Meningite B vacina",
         "Pentavalente  vacina","Streptococcus pneumoniae vacina","PAC vacina","Pneumonia bacteriana vacina","Otite Média Aguda vacina",
         "OMA vacina","pneumococo vacina","Sorotipo vacina","Sorogrupo vacina","Meningite Bacteriana vacina","Vacina conjugada vacina",
         "Vacina pollissacarídica vacina","Colonização nasofaríngea vacina","S. pneumonae vacina","Cepa pneumocócica vacina",
         "Marco Aurélio Safadi vacinação","Margareth Dalcomo vacinação","Angelica Rodrigues vacinação","Renato Kfouri vacinação",
         "Isabella Ballalai vacina","Rosana Richtmann vacina","SBIm vacina","Jornada de imunização vacina","Situação epidemiológica vacina",
         "Juarez Cunha vacina","Melissa Palmieri vacina","Monica Levi vacina","Clovis Arns vacina","Mauro Gomes vacina","Eitan Berezin vacina",
         "Ana Paula Burian vacina","Gecilmara Salviato vacina","Helena Sato vacina","Tania Petraglia vacina","encaminhamento do paciente de risco",
         "vacina RNA Comirnaty","vacina viva Nimenrix","vacina atenuada Nimenrix","vacina inativada Menveo","VPC15 vacina",
         "Pneumo 15 vacina","VPC10 vacina","Pneumo 10 vacina","VPC20 vacina","Pneumo 20 vacina","Pneumo 13 vacina",
         "resistência antimicrobiana vacina","VPP23 vacina","Pneumo 23 vacina"]

for i in Vacinas:
    #EXTRAIR METADADOS NOTICIAS 
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q":i,"lang":"pt","countries":"BR"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
            }
        
        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers, params=querystring).json()

        
        if response['articles']!=[]:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)
            
        else:
            df2=pd.DataFrame()
            df2[["id","title","link","published","sub_articles","source"]] = pd.DataFrame([["", "", "","","",""]])
            
            
        df2.insert(0,'company', i)
        df=pd.concat([df,df2], ignore_index=True, sort=False)
    
    
        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
            }
    except:
        pass

Vacinas_result=df
Vacinas_result=Vacinas_result.rename(columns={'company':'kw'})
Vacinas_result['categoria'] = 'Vacinas'





df=pd.DataFrame()

Hospitalar=["Gram-negativo","Analgesia multimodal","Dor Pós Operatória","Analgesia cirúrgica","Analgesia cirúrgica","Sem Opioides",
            "Poupar Opioide","AINE","COX2","Rápida Recuperação","Protocolo ERAS","Infecção bacteriana","Infecção fúngica","Anemia",
            "Anemia Ferropriva","Deficiência de ferro","Fadiga anemia","Cansaço anemia","Hemoglobina anemia","Hemograma anemia",
            "Resistência Bacteriana","Pseudomonas","KPC bacteria","Klebsiella","Sepse","Candidíase invasiva","Candidemia",
            "Candidemia na Pediatria","Pneumonia Adquirida em comunidade","Pneumonia","Candidemia invasiva","Infecção de Pele",
            "Aspergilose","Resistência a antibióticos ","Aeruginosa ","Coli bacteria","Pneumoniae","Referencia Aspergilose",
            "Stewardship antibiótico","Bacteremia","Infecção fúngica invasiva"]

for i in Hospitalar:
    #EXTRAIR METADADOS NOTICIAS 
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q":"Hos´pitalar "+i,"lang":"pt","countries":"BR"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
            }
        
        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers, params=querystring).json()

        
        if response['articles']!=[]:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)
            
        else:
            df2=pd.DataFrame()
            df2[["id","title","link","published","sub_articles","source"]] = pd.DataFrame([["", "", "","","",""]])
            
            
        df2.insert(0,'company', i)
        df=pd.concat([df,df2], ignore_index=True, sort=False)
    
    
        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
            }
    except:
        pass
    
Hospitalar_result=df
Hospitalar_result=Hospitalar_result.rename(columns={'company':'kw'})
Hospitalar_result['categoria'] = 'Hospitalar'




df=pd.DataFrame()

SNC=["Depressão","Ansiedade","Antidepressivos ","Sindrome do pânico","Sindrome do pânico","TDM","Transtorno Depressivo Maior",
     "Depressivo sintomas","Ansiosos sintomas","Saúde Mental","Doença Mental","Desmame medicamento","Pristiq","Elifore",
     "Desvenlafaxina","Deller","Desve ","Lexapro","Brintellix","Transtorno Mental","Escitalopram","Venlafaxina","Paroxetina",
     "Duloxetina","Sertralina","Miratazapina","Fluoxetina","Vortioxetina","Fluvoxamina","Agomelatina","Bupropiona",
     "Tristeza depressão","Suicídio Depressão","Ansiedade Depressão","Depressão Sintomas","Farmacogenética Depressão",
     "Teste farmacogenético Depressão","comorbidade Depressão","Interação medicamentosa","Efeito colateral Antidepressivo",
     "Efeito adverso Antidepressivo","Obesidade Depressão","Burnout","Pandemia Depressão","Covid Depressão","TAG ansiedade"]

for i in SNC:
    #EXTRAIR METADADOS NOTICIAS 
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q":"Sistema Nervoso "+i,"lang":"pt","countries":"BR"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
            }
        
        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers, params=querystring).json()

        
        if response['articles']!=[]:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)
            
        else:
            df2=pd.DataFrame()
            df2[["id","title","link","published","sub_articles","source"]] = pd.DataFrame([["", "", "","","",""]])
            
            
        df2.insert(0,'company', i)
        df=pd.concat([df,df2], ignore_index=True, sort=False)
    
    
        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
            }
    except:
        pass

SNC_result=df
SNC_result=SNC_result.rename(columns={'company':'kw'})
SNC_result['categoria'] = 'SNC'

# %%
SNC_result[['title', 'kw', 'published_date','link']].to_excel('./exported/SNC_result.xlsx')

# %%
import pymysql
import numpy as np
import datetime
import requests
import pandas as pd
import requests
import pandas as pd
from sqlalchemy import create_engine


print('Cardio')
df = pd.DataFrame()

Cardio = ["AVC", "Derrame", "Arritmia Cardíaca", "Fibrilação Atrial", "Fibrilação Atrial", "Trombose", "TVP", "TEV", "Embolia Pulmonar",
          "Insuficiência Cardíaca", "Cardiologia Pressão Alta", "Cardíaca Pressão Alta", "Cardio Pressão Alta"]

for i in Cardio:
    #EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q":"Cardiologia " + i, "lang": "pt", "countries": "BR"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass

Cardio_result = df
Cardio_result = Cardio_result.rename(columns={'company': 'kw'})
Cardio_result['categoria'] = 'Cardiologia'


print('Dermato')
df = pd.DataFrame()

Dermato = ["Adalimumabe", "Alopecia Areata", "Alto Custo", "Anticorpo Antidroga", "Anticorpo Antidroga", "Anticorpo Antidroga Neutralizante",
           "Artrite Psoriásica", "Artrite Psoriática", "baricitinibe", "Biológicos", "Biossimilar", "Biossimilares", "Biossimilaridade",
           "Dermatite", "Dermatite Atópica", "Doenças imunomediadas", "Doenças Inflamatórias", "Etanercepte", "inibidor da JAK", "Psoríase",
           "Psoríase em Placas", "secuquinumabe", "Terapia biológica", "Tofacitinibe", "Tuberculose", "upadacitinibe", "Ustequinumabe", "Vitiligo",
           "Dermatite Atópica", "SBD", "Hidradenite Supurativa", "Dupilumabe", "Dupixent", "Rinvoq", "Olumiant", "Sociedade Brasileira de Dermatologia",
           "Paulo Criado", "Roberto Takaoka", "Valeria Aoki", "Sociedade Brasileira de Alegia e Imunologia", "ASBAI", "Eczema",
           "Dermatite de contato", "Uticária", "Coceira ", "Pele sensível", "Prurido", "Depressão", "Absenteísmo", "AAD", "EADV ",
           "terapia sistemica", "JADE Pfizer", "Abrocinitibe"]

for i in Dermato:
    #EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q":"Dermatologia "+ i, "lang": "pt", "countries": "BR"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass

Dermato_result = df
Dermato_result = Dermato_result.rename(columns={'company': 'kw'})
Dermato_result['categoria'] = 'Dermatologia'


print('Reumato')
df = pd.DataFrame()

Reumato = ["abatacepte", "ACR - Colégio Americano de Reumatologia", "Adalimumabe", "Alto Custo", "Anticorpo Antidroga", "Anticorpo Antidroga Neutralizante",
           "Anticorpo Monoclonal", "Artrite", "Artrite Idiopática Juvenil", "Artrite Idiopática Juvenil Poliarticular", "Artrite Psoriásica",
           "Artrite Psoriática", "Artrite relacionada a Entesite", "Artrite Reumatoide", "baricitinibe", "Biológicos", "Biossimilar", "Biossimilares",
           "Biossimilaridade", "certolizumabe", "Congresso Brasileiro de Reumatologia", "Cristiano Campanholo", "Doenças imunomediadas",
           "Doenças Inflamatórias", "Dor articular", "Espondilite Anquilosante", "Espondiloartrite Axial não Radiográfica", "Etanercepte",
           "Liga Europeia contra o Reumatismo", "EULAR", "Fator de Necrose tumoral", "Herpes Zoster", "Infliximabe", "inibidor da JAK",
           "Karina Bonfiglioli", "Licia Mota", "LME", "Lombalgia", "Necrose tumoral", "Ricardo Xavier", "rituximabe", "Sebastião Radominski",
           "secuquinumabe", "Sociedade Brasileira de Reumatologia", "Terapia biológica", "tocilizumabe", "Tofacitinibe", "Trombose", "Tuberculose",
           "Ultra-som articular", "upadacitinibe", "Ustequinumabe", "Uveíte", "Uveíte Pediátrica", "Valderilio Feijó Azevedo", "Vedolizumabe",
           "upadacitinibe", "Dupilumabe", "Rinvoq", "Olumiant"]

for i in Reumato:
    #EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q":"Reumatologia "+ i, "lang": "pt", "countries": "BR"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass

Reumato_result = df
Reumato_result = Reumato_result.rename(columns={'company': 'kw'})
Reumato_result['categoria'] = 'Reumatologia'


print('Gastro')
df = pd.DataFrame()

Gastro = ["Adalimumabe", "Anticorpo Antidroga", "Anti-Neutralizing Drug Antibody", "Anticorpo Monoclonal", "Biológico", "Biossimilar",
          "Biossimilares", "Biossimilaridade", "Cicatrização de mucosa", "Colite", "Colite Ulcerativa", "Colonoscopia", "Coloproctologia",
          "Crohn", "Diarreia sintoma", "DII", "Doença de Crohn", "Doença de Crohn Fistulizante", "Doença Gastrintestinal",
          "Doença Inflamatória Intestinal", "Filgotinibe", "Gastroenterologia", "Manifestações extraintestinais", "PANCCO", "Paulo Kotze",
          "Retocolite", "Retocolite Ulcerativa", "SEBRADII", "Ultra-som intestinal", "terapia biológica", "Tofacitinibe", "Trombose", "Tuberculose",
          "UEGW", "Doenças imunomediadas", "Doenças inflamatórias", "ECCO-IBD", "Infliximabe", "IOIBD", "JAK", "LME"]

for i in Gastro:
    #EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q":"Gastroenterologia "+ i, "lang": "pt", "countries": "BR"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass

Gastro_result = df
Gastro_result = Gastro_result.rename(columns={'company': 'kw'})
Gastro_result['categoria'] = 'Gastroenterologia'


print('Onco')
df = pd.DataFrame()

Onco = ["Oncologia", "Onco", "Onco-Hemato", "Câncer", "Cancerígeno", "Cancerígena", "Carcinoma", "Neoplasia", "Tumor", "Imunoterapia", "Quimioterapia",
        "Hormonioterapia", "Terapia Alvo", "Transplante", "Medula Óssea", "Metástase", "Mestastático", "Células Anormais", "Nódulo", "Primeira Linha câncer",
        "Segunda Linha câncer", "Terceira Linha câncer", "Estágio I câncer", "Estágio II câncer", "Estágio III câncer", "Estágio IV câncer", "INCA",
        "ICESP", "Hospital do Amor", "AC Camargo", "Quinase", "Sobrevida", "Monoterapia", "Sobrevida Livre de Progressão", "SLP câncer"]

for i in Onco:
    #EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q": i, "lang": "pt", "countries": "BR"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass

Onco_result = df
Onco_result = Onco_result.rename(columns={'company': 'kw'})
Onco_result['categoria'] = 'Oncologia'


print('Hemato')
df = pd.DataFrame()

Hemato = ["Leucemia", "Leucemia Aguda", "Mielóide", "Linfóide", "LMA câncer", "LMC câncer", "LLA câncer", "LLC câncer", "Mieloma Múltiplo",
          "Leucemia Linfoblastica Aguda", "CD33 câncer", "anti-CD33 câncer", "ALFA-0701 câncer", "CD19 câncer", "CD22 câncer", "INO-VATE câncer",
          "Mieloide", "Leucemia linfoblástica aguda", "inotuzumabe Ozogamicina", "cromossomo philadelphia negativo", "DRM câncer", "Blinatumomabe",
          "Gentuzumabe", "InO câncer", "Blina câncer", "GO câncer", "LLA Ph+ câncer", "TCTH câncer", "CAR-T câncer", "BMT câncer", "Elranatamab",
          "Leucemia Mieloide Aguda", "Bosutinibe", "Dasatinibe", "Nilotinibe", "inotuzumabe", "Hemofilia"]

for i in Hemato:
    #EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q":"Hematologia " + i, "lang": "pt", "countries": "BR"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass

Hemato_result = df
Hemato_result = Hemato_result.rename(columns={'company': 'kw'})
Hemato_result['categoria'] = 'Hematologia'


print('Biossim')
df = pd.DataFrame()

Biossimilares = ["Biossimilar", "Biossimilaridade", "Imunogenicidade", "Intercambialidade", "Biossimilar Substituição automática", "Biossimilaridade Substituição automática", "Switch Biossimilar", "Cross Switch Biossimilar",
                 "Switch reverso Biossimilar", "Múltiplos switches Biossimilar", "Originador Biossimilar", "Referência Biossimilar", "DMARDS", "Biossimilar Biológicos",
                 "Rituximabe", "Trastuzumabe", "Bevacizumabe", "Libbs", "Sandoz", "Amgen", "Celltrion", "SOBRAFO Biossimilar", "FLAB Biossimilar",
                 "Valderilio Feijó Azevedo Biossimilar", "Terapia biológica", "intercambiabilidade biossimilar", "Infliximabe", "Adalimumabe"]

for i in Biossimilares:
    #EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q":"Biossimilares "+ i, "lang": "pt", "countries": "BR"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass

Biossimilares_result = df
Biossimilares_result = Biossimilares_result.rename(columns={'company': 'kw'})
Biossimilares_result['categoria'] = 'Biossimilares'


print('Onco')
df = pd.DataFrame()


print('Pfizer')
df = pd.DataFrame()

Pfizer = ["Pfizer", "Pfaizer", "Faizer", "Pifizer"]

for i in Pfizer:
    #EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q": i, "lang": "pt", "countries": "BR"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass

Pfizer_result = df
Pfizer_result = Pfizer_result.rename(columns={'company': 'kw'})
Pfizer_result['categoria'] = 'Pfizer'




Reumato_result[['title', 'kw', 'published_date','link']].to_excel('./exported/reumato.xlsx')
Biossimilares_result[['title', 'kw', 'published_date','link']].to_excel('./exported/Biossimilares.xlsx')

Gastro_result[['title', 'kw', 'published_date','link']].to_excel('./exported/gastro.xlsx')
Hemato_result[['title', 'kw', 'published_date','link']].to_excel('./exported/hemato.xlsx')
Pfizer_result[['title', 'kw', 'published_date','link']].to_excel('./exported/pfizer.xlsx')
Reumato_result[['title', 'kw', 'published_date','link']].to_excel('./exported/reumato.xlsx')
Onco_result[['title', 'kw', 'published_date','link']].to_excel('./exported/onco.xlsx')
# Out:
# Cardio
# Dermato
# Reumato
# Gastro
# Onco
# Hemato
# Biossim
# Onco
# Pfizer
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [1], line 410
#     404 Pfizer_result['categoria'] = 'Pfizer'
#     409 Reumato_result[['title', 'kw', 'published_date','link']].to_excel('./exported/reumato.xlsx')
# --> 410 Biossimilares_result[['title', 'kw', 'published_date','link']].to_excel('./exported/Biossimilares.xlsx')
#     411 Cardio_result[['title', 'kw', 'published_date','link']].to_excel('./exported/cardio.xlsx')
#     412 Gastro_result[['title', 'kw', 'published_date','link']].to_excel('./exported/gastro.xlsx')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\frame.py:3810, in DataFrame.__getitem__(self, key)
#    3808     if is_iterator(key):
#    3809         key = list(key)
# -> 3810     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3812 # take() does not accept boolean indexers
#    3813 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:6111, in Index._get_indexer_strict(self, key, axis_name)
#    6108 else:
#    6109     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6111 self._raise_if_missing(keyarr, indexer, axis_name)
#    6113 keyarr = self.take(indexer)
#    6114 if isinstance(key, Index):
#    6115     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:6171, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6169     if use_interval_msg:
#    6170         key = list(key)
# -> 6171     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6173 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6174 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['title', 'kw', 'published_date', 'link'], dtype='object')] are in the [columns]"

# %%
#Cardio_result[['title', 'kw', 'published_date','link']].to_excel('./exported/cardio.xlsx')
Hemato_result[['title', 'kw', 'published_date','link']].to_excel('./exported/hemato.xlsx')
