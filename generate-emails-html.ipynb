# %%
import pandas as pd

newsDF = pd.read_excel('noticias-newsletter.xlsx')

# %%
for i in newsDF.iterrows():
    categoria = i[1][0]
    news1 = i[1][1]
    try:
      data1 = (i[1][3]).strftime("%d/%m/%Y")
    except:
      data1 = i[1][3]
    link1 = i[1][4]
    news2 = i[1][5]
    try:
      data2 = (i[1][7]).strftime("%d/%m/%Y")
    except:
      data2 = (i[1][7])
    link2 = i[1][8]
    news3 = i[1][9]
    try:
      data3 = (i[1][11]).strftime("%d/%m/%Y")
    except:
      data3 = (i[1][11])
    link3 = i[1][12]
    
    news4 = i[1][13]
    try:
      data4 = (i[1][15]).strftime("%d/%m/%Y")
    except:
      data4 = (i[1][15])
    link4 = i[1][16]
    news5 = i[1][17]
    try:
      data5 = (i[1][19]).strftime("%d/%m/%Y")
    except:
      data5 = (i[1][19])
    link5 = i[1][20]
    news6 = i[1][21]
    try:
      data6 = (i[1][23]).strftime("%d/%m/%Y")
    except:
      data6 = (i[1][23])
    link6 = i[1][24]

    html = """
      <!DOCTYPE html>
      <br>

      <head>
        <style>
          body {
            padding: 20px;
          }

          p,
          h1,
          h2,
          h3,
          h4,
          span {
            font-family: 'Roboto', sans-serif;
            color: #212121;
          }

          table {
            font-family: 'Roboto', sans-serif;
            color: #212121;
            width: 100%;
          }

          td {
            max-width: 100px;
          }

          td,
          th {
            border: 1px solid #dddddd;
            text-align: left;
            padding: 8px;
            border-bottom: 1px solid #dddddd;
            border-top: none;
            border-right: none;
            border-left: none;

          }

          tr:nth-child(even) {}

          h1 {
            margin-left: auto;
            margin-right: auto;
            margin-top: 10px;
            margin-bottom: 50px;
          }

          .logo {
            width: 100%;
            height: auto;

          }

          span {
            color: darkblue;
          }

          button {
            height: 60px;
            background-color: #0095FF;
            border-style: none;
            border-radius: 10px;
          }

          .button-span {
            font-weight: bold;
            color: darkblue;
            font-size: 15px;
          }

          a {
            text-decoration: none;
          }
        </style>

        <link href='http://fonts.googleapis.com/css?family=Roboto' rel='stylesheet' type='text/css'>
      </head>

      <body>
        <img src="https://storage.googleapis.com/email-image-source/email-banner.png"
          style="width: 100%; height: auto;">
        <div style="margin-bottom: 30px; margin-top: 30px;">
          <p style="margin: 0;">
            Seja bem-vindo(a) a sua newsletter personalizada do Content Pulse! Descubra as novidades sobre o seu tema de
            interesse:
          </p>
        </div>

        <h4 style="margin: 0; color: #0095FF;">#"""+categoria+"""</h4>

        <h4 style="margin-top: 30px; margin-bottom: 10px;">Últimas notícias do Brasil </h4>
        <table>
          <thead style="background-color: #dddddd;">
            <th>Notícia</th>
            <th>Data</th>
            <th>Link</th>      
          </thead>
          <tr>
              <td>"""+news1+"""</td>
              <td>"""+str(data1)+"""</td>
              <td><a
                  href=" """+link1+"""">Link</a>
              </td>
          </tr>
          
          <tr>
              <td>"""+news2+"""</td>
              <td>"""+str(data2)+"""</td>
              <td><a
                  href=" """+link2+"""">Link</a>
              </td>
          </tr>
          
          <tr>
              <td>"""+news3+"""</td>
              <td>"""+str(data3)+"""</td>
              <td><a
                  href=" """+link3+"""">Link</a>
              </td>
          </tr>
          
        </table>

        <h4 style="margin-top: 20px; margin-bottom:  10px ;">Últimas notícias do Mundo </h4>
        <table>
          <thead style="background-color: #dddddd;">
            <th>Notícia</th>
            <th>Data</th>
            <th>Link</th>
          </thead>
          <tr>
              <td>"""+news4+"""</td>
              <td>"""+str(data4)+"""</td>
              <td><a
                  href=" """+link4+"""">Link</a>
              </td>
          </tr>
          <tr>
              <td>"""+news5+"""</td>
              <td>"""+str(data5)+"""</td>
              <td><a
                  href=" """+link5+"""">Link</a>
              </td>
          </tr>
          <tr>
              <td>"""+news6+"""</td>
              <td>"""+str(data6)+"""</td>
              <td><a
                  href=" """+link6+"""">Link</a>
              </td>
          </tr>
        </table>
        </br>

        <div style="display:flex;">
          <button style="margin: 0px auto ;"><a href="https://www.orbitdatascience-hub.com/pfizer-pulse-dashboard-news"><span
                class="button-span">Acessar Dashboard</span></a></button>
        </div>
        <p style="font-style: italic ; font-size: small;">*Senha de acesso ao Dashboard: pulse@0311 </p>
      </body>

      </html>
      """

    with open('./html/'+categoria+'.html', 'w', encoding='utf-8') as f:
        (f.write(html))
