# %%
import pymysql
import numpy as np
import datetime
import requests
import pandas as pd
import requests

import pandas as pd

from sqlalchemy import create_engine


df = pd.DataFrame()

Cardio = ["CVA", "stroke", "cardiac arrythmia", "Atrial Fibrillation", "Thrombosis ", "DVT", "VTE", "Pulmonary Embolism", "Heart Failure",
          "High blood pressure", "Hypertension", ]

for i in Cardio:
    # EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        #querystring = {"q":i,"lang":"pt","countries":"BR"}
        querystring = {"q": i, "lang": "en"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        # COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass


Cardio_result = df
Cardio_result = Cardio_result.rename(columns={'company': 'kw'})
Cardio_result['categoria'] = 'Cardiologia'


df = pd.DataFrame()

Dermato = ["Adalimumab", "Alopecia Areata", "High Cost", "Anti-drug antibody", "Anti-Neutralizing Drug Antibody", "psoriatic arthritis",
           "psoriatic arthritis", "baricitinib", "Biological", "Biosimilar", "Biosimilars", "Biosimilarity", "Dermatitis", "Atopic Dermatitis",
           "Immune-mediated diseases", "Inflammatory Diseases", "Etanercept", "JAK inhibitor", "JAK", "Psoriasis", "Plaque Psoriasis", "secukinumab",
           "biological therapy", "Tofacitinib", "Tuberculosis", "upadacitinib", "Ustekinumab", "Vitiligo", "Atopic Dermatitis", "SBD",
           "Hidradenitis Suppurativa", "Dupilumab", "Dupixent ", "Rinvoq ", "Olumiant ", "Brazilian Society of Dermatology", "Paulo Criado",
           "Roberto Takaoka ", "Valeria Aoki ", "Brazilian Society of Allegy and Immunology", "ASBAI", "Eczema", "Contact dermatitis",
           "Urticaria", "Itch", "Sensitive skin", "pruritus", "depression", "absenteeism", "AAD ", "EADV ", "systemic therapy", "JADE pfizer",
           "Abrocinitib", "JAK 1", "JAK 2 ", "JAK 3", "skin allergy"]

for i in Dermato:
    # EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        #querystring = {"q":i,"lang":"pt","countries":"BR"}
        querystring = {"q": i, "lang": "en"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        # COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass


Dermato_result = df
Dermato_result = Dermato_result.rename(columns={'company': 'kw'})
Dermato_result['categoria'] = 'Dermatologia'


df = pd.DataFrame()

Reumato = ["abatacept", " American College of Rheumatology", "", "Adalimumab", "High cost", "Anti-drug antibody", "Anti-Neutralizing Drug Antibody",
           "Monoclonal Antibody", "Arthritis", "Juvenile Idiopathic Arthritis", "Polyarticular Juvenile Idiopathic Arthritis", "psoriatic arthritis",
           "psoriatic arthritis", "Enthesitis Related Arthritis", "Rheumatoid arthritis", "baricitinib", "Biological", "Biosimilar", "Biosimilars",
           "Biosimilarity", "Certolizumab", "Brazilian Congress of Rheumatology", "Cristiano Campanholo", "Immune-mediated diseases",
           "Inflammatory Diseases", "joint pain", "Ankylosing spondylitis", "Non-Radiographic Axial Spondyloarthritis", "Etanercept",
           "European League against Rheumatism", "EULAR", "tumor necrosis factor", "Herpes Zoster", "Infliximab", "JAK inhibitor", "JAK",
           "Karina Bonfiglioli", "Licia Mota", "LME", "Backache", "tumor necrosis", "Ricardo Xavier", "rituximabe", "Sebastião Radominski",
           "secukinumab", "Brazilian Society of Rheumatology", "biological therapy", "tocilizumab", "Tofacitinib", "Thrombosis", "Tuberculosis",
           "Joint ultrasound", "upadacitinib", "Ustekinumab", "uveitis", "Pediatric Uveitis", "Valderilio Feijó Azevedo", "Vedolizumab", "upadacitinib",
           "Dupilumabe", "Rinvoq", "Olumiant"]

for i in Reumato:
    # EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        #querystring = {"q":i,"lang":"pt","countries":"BR"}
        querystring = {"q": i, "lang": "en"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        # COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass


Reumato_result = df
Reumato_result = Reumato_result.rename(columns={'company': 'kw'})
Reumato_result['categoria'] = 'Reumatologia'


df = pd.DataFrame()

Gastro = ["Adalimumab", "Anti-drug antibody", "Anti-Neutralizing Drug Antibody", "Monoclonal Antibody", "Biological", "Biosimilar", "Biosimilars",
          "Biosimilarity", "Mucosal healing", "Colitis", "Ulcerative Colitis", "Colonoscopy", "Coloproctology", "Crohn", "diarrhea cancer", "DII",
          "Crohn's disease", "Crohn's Disease Fistulizing", "Gastrointestinal Disease", "Inflammatory Bowel Disease", "Filgotinib", "Gastroenterology",
          "Extra-intestinal manifestations", "PANCCO", "Paulo Kotze", "Rectocolitis", "Ulcerative Colitis", "SEBRADII", "intestinal ultrasound",
          "biological therapy", "Tofacitinib", "Thrombosis", "Tuberculosis", "UEGW", "Immune-mediated diseases", "Inflammatory Diseases", "ECCO-IBD",
          "Infliximab", "IOIBD", "JAK", "LME"]

for i in Gastro:
    # EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        #querystring = {"q":i,"lang":"pt","countries":"BR"}
        querystring = {"q": i, "lang": "en"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        # COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass


Gastro_result = df
Gastro_result = Gastro_result.rename(columns={'company': 'kw'})
Gastro_result['categoria'] = 'Gastroenterologia'


df = pd.DataFrame()

Onco = ["Oncology", "Onco", "hematologist-oncologist", "Cancer", "Carcinogenic", "Carcinoma", "Neoplasm", "Tumor", "Immunotherapy", "Chemotherapy",
        "Hormone therapy", "Targeted therapy", "Transplant", "bone marrow", "Metastasis", "Metastatic", "Abnormal cells", "Nodule", "First line treatment",
        "Second line treatment", "Third line treatment", "Stage I", "Stage II", "Stage III", "Stage IV", "INCA", "ICESP", "Hospital do Amor",
        "AC Camargo", "Kinase", "Overall survival", "Monotherapy", "Progression Free Survival", "PFS"]

for i in Onco:
    # EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        #querystring = {"q":i,"lang":"pt","countries":"BR"}
        querystring = {"q": i, "lang": "en"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        # COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass


Onco_result = df
Onco_result = Onco_result.rename(columns={'company': 'kw'})
Onco_result['categoria'] = 'Oncologia'


df = pd.DataFrame()

Hemato = ["Acute Leukemia", "Leukemia", "Myeloid", "Lymphoid", "AML cancer", "CML cancer", "ALL cancer", "CLL cancer", "Multiple Myeloma",
          "Acute Lymphoblastic Leukemia", "CD33 cancer", "anti-CD33 cancer", "ALFA-0701 cancer", "CD19 cancer", "CD22 cancer", "INO-VATE study cancer",
          "Myeloid", " Acute Lymphoblastic Leukemia", "Inotuzumab Ozogamicin", "Relapsed/Refractory (R/R)", "Philadelphia chromosome-negative",
          "MRD cancer", "Blinatumomab", "Gentuzumab", "InO cancer", "Blina cancer", "GO cancer", "ALL Ph+ cancer", "HSCT cancer", "CAR-T cancer",
          "BMT cancer", "Elranatamab", "Acute Myeloid Leukemia", "Bosutinib", "Dasatinib", "Nilotinib", "Inotuzumab"]

for i in Hemato:
    # EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        #querystring = {"q":i,"lang":"pt","countries":"BR"}
        querystring = {"q": i, "lang": "en"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        # COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass


Hemato_result = df
Hemato_result = Hemato_result.rename(columns={'company': 'kw'})
Hemato_result['categoria'] = 'Hematologia'


df = pd.DataFrame()

Biossimilares = ["Biosimilar", "Biosimilarity", "Immunogenicity", "Interchangeability Biosimilar", "automatic replacement", "Drug switch Biosimilar", "Cross Switch Biosimilar",
                 "Reverse Switch Biosimilar", "Multiple switches Biosimilar", "Originator product Biosimilar", "Reference Biosimilar", "DMARDs", "Biological Medicine", "Rituximab", "Trastuzumab",
                 "Bevacizumab", "Libbs", "Sandoz", "Amgen", "Celltrion", "SOBRAFO", "FLAB", "Valderilio Feijó Azevedo", "Biological Therapy",
                 "Interchangeability Biosimilar", "Infliximab", "Adalimumab"]

for i in Biossimilares:
    # EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        #querystring = {"q":i,"lang":"pt","countries":"BR"}
        querystring = {"q": i, "lang": "en"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        # COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass


Biossimilares_result = df
Biossimilares_result = Biossimilares_result.rename(columns={'company': 'kw'})
Biossimilares_result['categoria'] = 'Biossimilares'


df = pd.DataFrame()

OncologiaMama = ["Breast Cancer", "Palbociclib", "Abemaciclib", "Ribociclib", "Exemestane", "Talazoparib", "CDK cancer", "iCDK cancer", "Cycline cancer",
                 "HER2 cancer", "HR+ cancer", "HR- cancer", "HER2+ cancer", "ER+ cancer", "ER- cancer", "BRCA1 cancer", "BRCA2 cancer", "CDK 4/6 cancer",
                 "mBC cancer", "human epidermal growth factor receptor 2", "Metastatic Breast Cancer", "Advanced Breast Cancer", "Cycline Inhibitor",
                 "PALOMA-1 cancer", "PALOMA-2 cancer", "PALOMA-3 cancer", "IRIS cancer", "FLATIRON cancer", "PALOMAGE cancer", "Estrogen receptor",
                 "Hormone receptor", "D1 Cyclin", "PARPi", "PARP inhibitor", "EMBRACA", "TALAPRO-1 ", "Locally advanced breast cancer",
                 "germline mutation in BRCA", "Trastuzumab"]

for i in OncologiaMama:
    # EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        #querystring = {"q":i,"lang":"pt","countries":"BR"}
        querystring = {"q": i, "lang": "en"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        # COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass


OncologiaMama_result = df
OncologiaMama_result = OncologiaMama_result.rename(columns={'company': 'kw'})
OncologiaMama_result['categoria'] = 'Oncologia(Mama)'


df = pd.DataFrame()

OncologiaRCC = ["Kidney cancer", "Bladder Cancer", "Kidney neoplasm", "Gastrointestinal tract ", "Pancreatic neuroendocrine tumors",
                "Immunotherapy", "Urothelial", "Urothelial Carcinoma", "anti-VEGF", "Adjuvancy treatment", "Kidney cell", "Avanced carcinoma",
                "Green June", "Pazopanib", "Avelumab", "Sunitinib", "Axitinib", "Oncoguia", "Vencer o cancer", "IVOC", "Fernando Maluf cancer",
                "cytokine ", " VEGF receptors ", "sorafenib", "ADONIS cancer", "Metastatic Kidney Cells", "Combination therapy", "advanced RCC",
                "GIST cancer", "PNETs", "Liposarcoma", "tyrosine kinase inhibitors", "VEGFR", "PDGFRB", "pembrolizumab",
                "Ipi + Nivo", "Javelin Renal 101", "PD-L1", "SBU cancer", "CCRm", "TKI + IO", "Keytruda", "AxItinib + IO"]

for i in OncologiaRCC:
    # EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        #querystring = {"q":i,"lang":"pt","countries":"BR"}
        querystring = {"q": i, "lang": "en"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        # COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass


OncologiaRCC_result = df
OncologiaRCC_result = OncologiaRCC_result.rename(columns={'company': 'kw'})
OncologiaRCC_result['categoria'] = 'Oncologia(RCC)'


df = pd.DataFrame()

OncologiaPulmao = ["Lung Cancer", "Lung Tumor", "ROS1", "ALK cancer", "Crizotinib", "Lorlatinib", "Dacomitinib", "Crown Study",
                   "Alectinib", "Brigatinb", "Ensartinib", "NSCLC", "ALK-Postive", "ALK+ cancer", "EML4-ALK", "Inibidor de ALK",
                   "ALK TKI", "anaplastic lymphoma kinase", "alk fusion oncogene", "ROS1+", "ROS1 gene fusions", "ROS1 rearrangement",
                   "ROS1-Positive", "Profile 1014", "Profile 1001", "non-small cell lung cancer", "entrectinib", "ALK rearrangement",
                   "ALK gene fusion", "ALK oncogene", "NSCLC ALK+", "Metastatic lung câncer", "Stage IV lung câncer"]

for i in OncologiaPulmao:
    # EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        #querystring = {"q":i,"lang":"pt","countries":"BR"}
        querystring = {"q": i, "lang": "en"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        # COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass


OncologiaPulmao_result = df
OncologiaPulmao_result = OncologiaPulmao_result.rename(
    columns={'company': 'kw'})
OncologiaPulmao_result['categoria'] = 'Oncologia(Pulmão)'


df = pd.DataFrame()

OncologiaMelanoma = ["Skin cancer", "Melanoma", "Colorectal", "Pierre Fabre", "binimetinib", "encorafenib", "Skin Carcinoma", "Epidermis",
                     "Dermis", "Braftovi", "Mektovi", "UV cancer", "BRAF cancer", "MEK cancer", "RAF cancer", "NF1 cancer", "NRAS cancer",
                     "HRAS cancer", "KRAS cancer", "GNAQ cancer", "GNA11 cancer", "cKIT cancer", "MAPK cancer", "BRAF V600 cancer",
                     "Cobimetinib", "Dacarbazine", "Ipilimimabe", "Vemurafenib", "Dabrafenib", "Trametinib", "Epithelial"]

for i in OncologiaMelanoma:
    # EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        #querystring = {"q":i,"lang":"pt","countries":"BR"}
        querystring = {"q": i, "lang": "en"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        # COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass


OncologiaMelanoma_result = df
OncologiaMelanoma_result = OncologiaMelanoma_result.rename(columns={
                                                           'company': 'kw'})
OncologiaMelanoma_result['categoria'] = 'Oncologia(Melanoma)'


df = pd.DataFrame()

Pfizer = ["Pfizer", "Pfaizer", "Faizer", "Pifizer"]

for i in Pfizer:
    # EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        #querystring = {"q":i,"lang":"pt","countries":"BR"}
        querystring = {"q": i, "lang": "en"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        # COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass


Pfizer_result = df
Pfizer_result = Pfizer_result.rename(columns={'company': 'kw'})
Pfizer_result['categoria'] = 'Pfizer'


finaldata = pd.concat([Biossimilares_result, Cardio_result], axis=0)
finaldata = pd.concat([finaldata, Dermato_result], axis=0)
finaldata = pd.concat([finaldata, Gastro_result], axis=0)
finaldata = pd.concat([finaldata, Hemato_result], axis=0)
finaldata = pd.concat([finaldata, Pfizer_result], axis=0)
finaldata = pd.concat([finaldata, Reumato_result], axis=0)
finaldata = pd.concat([finaldata, Onco_result], axis=0)
finaldata = pd.concat([finaldata, OncologiaMama_result], axis=0)
finaldata = pd.concat([finaldata, OncologiaRCC_result], axis=0)
finaldata = pd.concat([finaldata, OncologiaPulmao_result], axis=0)
finaldata = pd.concat([finaldata, OncologiaMelanoma_result], axis=0)


finaldata = finaldata.rename(
    columns={'published_date': 'published', '_id': 'id'})
finaldata1 = finaldata[['kw', 'id', 'title', 'link', 'published', 'categoria']]

###
# def convert_date(s):
#     month_dict = {'Jan':'01', 'Feb':'02', 'Mar':'03', 'Apr':'04', 'May':'05', 'Jun':'06',
#                   'Jul':'07', 'Aug':'08', 'Sep':'09', 'Oct':'10', 'Nov':'11', 'Dec':'12'}

#     try:
#         d = s.split(" ")[1]
#         m = month_dict[s.split(" ")[2]]
#         y = s.split(" ")[3]
#     except:
#         return ""

#     return f'{d}-{m}-{y}'

# finaldata1["published"] = finaldata1["published"].apply(convert_date)

finaldata1['published'] = pd.to_datetime(
    finaldata1['published'], errors="coerce", dayfirst=True)


# INSERT NO DB

host1 = 'pfizerdb.cqxct8aqwlso.us-east-2.rds.amazonaws.com'
port1 = '3306'
user1 = 'pfizer'
passw1 = 'P!zer2597!'
database1 = 'pfizerdb'

mydb1 = create_engine('mysql+pymysql://' + user1 + ':' + passw1 +
                      '@' + host1 + ':' + str(port1) + '/' + database1, echo=False)
finaldata1.to_sql(name='google_news_mundo_v2', con=mydb1,
                  if_exists='append', index=False)
# Out:
# C:\Users\flavi\AppData\Local\Temp\ipykernel_78020\4151538761.py:649: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   finaldata1['published'] = pd.to_datetime(
# 13155

# %%
import requests
import pandas as pd
import requests

import pandas as pd
import pymysql
from sqlalchemy import create_engine




df=pd.DataFrame()

DRATTR=["amyloidosis","tafamidis","Vyndaqel","Vyndamax","Onpattro","Patisiran","Tegsedi","inotersen","vutrisirana",
        "FAP Familial Amyloidotic Polyneuropathy","familial amyloidotic polyneuropathy","cardiac amyloidosis","ATTR",
        "Cardiac Insufficiency","ICFEp","QSART","Sudoscan","Protocol Cardiac Insufficiency","wATTR","hATTR","carpal tunnel syndrome",
        "Transthyretin amyloidosis","Ventricular hypertrophy","Cardiomyopathy","ATTR-CM","ATTR-PN","Amyloid cardiomyopathy",
        "Transthyretin amyloidotic cardiomyopathy","FAC Familial Amyloidotic Familiar","Familial amyloid cardiomyopathy","ATTRwt",
        "ATTRh","ATTRm","ATTRv","Val30Met","Val50Met","V30M","V50M","Val122Ile","Val142Ile","V122I","V142I",
        "restrictive cardiomyopathy","Preserved ejection fraction","Wild-type ATTz","Hereditary ATTR","TTR mutation",
        "Acoramidis","AG-10","TTR stabilizer","TTR Gene Silencers","ABPAR","TTR sequencing","ATTR Genetic test",
        "Red Flags PAF","Red Flags ATTR-CM","Hereditary disease"]

for i in DRATTR:
    #EXTRAIR METADADOS NOTICIAS 
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        #querystring = {"q":i,"lang":"pt","countries":"BR"}
        querystring = {"q":i,"lang":"en"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
            }
        
        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers, params=querystring).json()

        
        if response['articles']!=[]:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)
            
        else:
            df2=pd.DataFrame()
            df2[["id","title","link","published","sub_articles","source"]] = pd.DataFrame([["", "", "","","",""]])
            
            
        df2.insert(0,'company', i)
        df=pd.concat([df,df2], ignore_index=True, sort=False)
    
    
        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
            }
    except:
        pass

DRATTR_result=df
DRATTR_result=df
DRATTR_result=DRATTR_result.rename(columns={'company':'kw'})
DRATTR_result['categoria'] = 'ATTR'




df=pd.DataFrame()

DREndocrineCare = ["growth children","somatropin","Genotropin","growth hormone","GH","Long-Acting GH","grow up kchildren",
                   "short stature children","Prader Willi","Turner Syndrome","ISS short","Idiopathic short stature",
                   "growth disorder children","GHD","Norditropin","Saizen","hormotrop","Omnitrope","pediatric endocrine",
                   "Endoped","child growth","Pediatric Endocrinology","Pediatrics child growth","Growth hormone",
                   "Child development growth","growth phases children","Height forecast children","growth curve",
                   "growth speed children","SGA growth","small gestational age","growth hormone deficiency",
                   "family channel growth","age weight curve growth","Stretch growth","GH Safety growth",
                   "short stature investigation children","Exome growth","Karyotype turner syndrome",
                   "genetic study children","short stature children","Tanner's formula","food and growth children",
                   "estimated height children","target height children","webbed neck turner syndrome","IGF-1 child growth",
                   "IGFBP-3 child growth","DNA metilation Prader-Willi syndrome","Hypotonia Prader-Willi syndrome"]

for i in DREndocrineCare:
    #EXTRAIR METADADOS NOTICIAS 
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        #querystring = {"q":i,"lang":"pt","countries":"BR"}
        querystring = {"q":i,"lang":"en"}
        
        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
            }
        
        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers, params=querystring).json()

        
        if response['articles']!=[]:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)
            
        else:
            df2=pd.DataFrame()
            df2[["id","title","link","published","sub_articles","source"]] = pd.DataFrame([["", "", "","","",""]])
            
            
        df2.insert(0,'company', i)
        df=pd.concat([df,df2], ignore_index=True, sort=False)
    
    
        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
            }
    except:
        pass
DREndocrineCare_result=df
DREndocrineCare_result=df
DREndocrineCare_result=DREndocrineCare_result.rename(columns={'company':'kw'})
DREndocrineCare_result['categoria'] = 'EndocrineCare'






df=pd.DataFrame()

DRTransplante = ["imTOR","sirolimus","rapamycin","Rapamune","kidney transplant","transplant patient kidney","ABTO transplant",
                 "organ transplantation","everolimus","Certican","Immunosuppression Protocol kidney","immunosuppression kidney",
                 "kidney transplant","kidney loss","kidney function","hemodialysis","kidney transplant list",
                 "Brazilian Association of Organ Transplants","Late Kidney Function","Mycophenolate","prednisone","Cyclosporine",
                 "Azathioprine","LAM","Lymphangioleiomyomatosis","Graft kidney","graft loss kidney","proteinuria kidney",
                 "organ rejection kidney","Polyomavirus","organ compatibility transplant","CMV","Cytomegalovirus","PCR exam",
                 "Blood level of the immunosuppressant","Blood dose of the immunosuppressant","BK virus","glomerular filtration",
                 "clinial Protocol and therapeutic guidelines transplant","Mycophenolate Sodium","viral infections transplant"]

for i in DRTransplante:
    #EXTRAIR METADADOS NOTICIAS 
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        #querystring = {"q":i,"lang":"pt","countries":"BR"}
        querystring = {"q":i,"lang":"en"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
            }
        
        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers, params=querystring).json()

        
        if response['articles']!=[]:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)
            
        else:
            df2=pd.DataFrame()
            df2[["id","title","link","published","sub_articles","source"]] = pd.DataFrame([["", "", "","","",""]])
            
            
        df2.insert(0,'company', i)
        df=pd.concat([df,df2], ignore_index=True, sort=False)
    
    
        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
            }
    except:
        pass

DRTransplante_result=df
DRTransplante_result=df
DRTransplante_result=DRTransplante_result.rename(columns={'company':'kw'})
DRTransplante_result['categoria'] = 'Transplante'






df=pd.DataFrame()

DRHemofilia = ["Factor VIII hemophilia","Factor IX hemophilia","Recombinant Factor hemophilia","plasma factor hemophilia","Hemophilic",
               "BenefiX","alfanonacogue","Xyntha","alfamoroctocogue","Elprolix","alfaeftrenonacogue","Rixubis","gamanonacogue",
               "bleeding hemophilia"]

for i in DRHemofilia:
    #EXTRAIR METADADOS NOTICIAS 
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        #querystring = {"q":i,"lang":"pt","countries":"BR"}
        querystring = {"q":i,"lang":"en"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
            }
        
        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers, params=querystring).json()

        
        if response['articles']!=[]:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)
            
        else:
            df2=pd.DataFrame()
            df2[["id","title","link","published","sub_articles","source"]] = pd.DataFrame([["", "", "","","",""]])
            
            
        df2.insert(0,'company', i)
        df=pd.concat([df,df2], ignore_index=True, sort=False)
    
    
        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
            }
    except:
        pass

DRHemofilia_result=df
DRHemofilia_result=df
DRHemofilia_result=DRHemofilia_result.rename(columns={'company':'kw'})
DRHemofilia_result['categoria'] = 'Hemofilia'






df=pd.DataFrame()

DRPipeline = ["genetic therapy","gene therapy","Exondys 51","eteplirsen","Vyondys","golodirsen","Vyondys 53","Amondys 45","casimersen",
              "zolgensma","onasemnogene abeparvovec","Luxturna","voretigene neparvovec","Spinraza","nusinersen","Soliris","eculizumabe",
              "Duchenne","Rare diseases","genetic test", "duchenne muscular dystrophy"]

for i in DRPipeline:
    #EXTRAIR METADADOS NOTICIAS 
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        #querystring = {"q":i,"lang":"pt","countries":"BR"}
        querystring = {"q":i,"lang":"en"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
            }
        
        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers, params=querystring).json()

        
        if response['articles']!=[]:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)
            
        else:
            df2=pd.DataFrame()
            df2[["id","title","link","published","sub_articles","source"]] = pd.DataFrame([["", "", "","","",""]])
            
            
        df2.insert(0,'company', i)
        df=pd.concat([df,df2], ignore_index=True, sort=False)
    
    
        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
            }
    except:
        pass

DRPipeline_result=df
DRPipeline_result=df
DRPipeline_result=DRPipeline_result.rename(columns={'company':'kw'})
DRPipeline_result['categoria'] = 'Terapia Gênica'






df=pd.DataFrame()

DROutros = ["Pfizer Academy","EBEP","Brazilian Meeting of Pediatric Endocrinology","COBRAPEM endocrinology",
            "Congresso Brasileiro Pediátrico de Endocrinologia e Metabologia","SLEP endocrinology",
            "Sociedad Latino-Americana de Endocrinología Pediátric","The Endocrine Society Annual Meeting","ATC",
            "American Transplant Congress","HEMO","Brazilian Congress of Neurology","Brazilian Congress of Cardiology",
            "Brazilian Congress of Medical Genetics","PNS Peripheral Nerve Society","Brazilian Congress of Nuclear Medicine",
            "European Society of Cardiology","European Society of Cardiology","American Heart Association",
            "American Heart Association","American College of Cardiology"," American College of Cardiology","SOCESP",
            "sociedade de cardiologia do estado de são paulo","SINE","Brazilian Congress of Endocrinology and Metabolism",
            "ESPE","European Society for Paediatric Endocrinology","São Paulo Congress of Endocrinology and Metabolism",
            "COPEM","American Transplant Congress","European Congress on Transplants","Brazilian Congress on Transplants",
            "ABTO","Brazilian Congress on Organ Transplants","Minas Gerais Transplant Congress","Brazilian Congress of Nephrology",
            "São Paulo Congress of Nephrology"]

for i in DROutros:
    #EXTRAIR METADADOS NOTICIAS 
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        #querystring = {"q":i,"lang":"pt","countries":"BR"}
        querystring = {"q":i,"lang":"en"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
            }
        
        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers, params=querystring).json()

        
        if response['articles']!=[]:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)
            
        else:
            df2=pd.DataFrame()
            df2[["id","title","link","published","sub_articles","source"]] = pd.DataFrame([["", "", "","","",""]])
            
            
        df2.insert(0,'company', i)
        df=pd.concat([df,df2], ignore_index=True, sort=False)
    
    
        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
            }
    except:
        pass

DROutros_result=df
DROutros_result=df
DROutros_result=DROutros_result.rename(columns={'company':'kw'})
DROutros_result['categoria'] = 'Outros'



df=pd.DataFrame()

Vacinas=["CRIE vaccine","Vaccination campaign pneumonia","Pneumococcal disease vaccine","meningococcal disease vaccine","Covid vaccine",
         "PCV13","Pneumococcal Pneumonia","Vaccine pneumonia","Vaccination pneumonia","where to vaccinate","Referral of patients at risk vaccine",
         "Minister of Health vaccine","Vaccination center menveo","meningococcal meningitis vaccine","ACWY  vaccine","Meningitis C vaccine",
         "Meningitis B vaccine","Pentavalent vaccine","Streptococcus pneumoniae vaccine","Community-acquired pneumonia vaccine","CAP vaccine",
         "Bacterial pneumonia vaccine","Acute otitis media vaccine","AOM vaccine","pneumococcus vaccine","Serotype vaccine","Serogroup vaccine",
         "Bacterial Meningitis vaccine","conjugate vaccine pneumonia","Polysaccharide vaccine pneumonia","nasopharyngeal colonization vaccine",
         "S. pneumonae vaccine","Pneumococcal strain vaccine","Marco Aurélio Safadi vaccine","Margareth Dalcomo vaccine",
         "Angelica Rodrigues vaccine","Renato Kfouri vaccine","Isabella Ballalai  vaccine","Rosana Richtmann vaccine","SBIm vaccine",
         "Immunization journey vaccine","Epidemiological situation vaccine","Juarez Cunha vaccine","Melissa Palmieri vaccine",
         "Monica Levi vaccine","Clovis Arns vaccine","Mauro Gomes vaccine","Eitan Berezin vaccine","Ana Paula Burian vaccine",
         "Gecilmara Salviato vaccine","Helena Sato vaccine","Tania Petraglia vaccine","vaccine efficacy Nimenrix","vaccine security Nimenrix",
         "RNA vaccine Comirnaty ","live vaccine Nimenrix","attenuated vaccine Nimenrix","inactivated vaccine Nimenrix","PCV15 vaccine",
         "Pneumo 15 vaccine","PCV10 vaccine","Pneumo 10 vaccine","PCV20 vaccine","Pneumo 20 vaccine","Pneumo 13 vaccine",
         "antimicrobial resistance vaccine","PPSV23 vaccine","Pneumo 23 vaccine","Prevnar 13 ","In-home vaccination pneumonia"]

for i in Vacinas:
    #EXTRAIR METADADOS NOTICIAS 
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        #querystring = {"q":i,"lang":"pt","countries":"BR"}
        querystring = {"q":i,"lang":"en"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
            }
        
        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers, params=querystring).json()

        
        if response['articles']!=[]:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)
            
        else:
            df2=pd.DataFrame()
            df2[["id","title","link","published","sub_articles","source"]] = pd.DataFrame([["", "", "","","",""]])
            
            
        df2.insert(0,'company', i)
        df=pd.concat([df,df2], ignore_index=True, sort=False)
    
    
        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
            }
    except:
        pass

Vacinas_result=df
Vacinas_result=Vacinas_result.rename(columns={'company':'kw'})
Vacinas_result['categoria'] = 'Vacinas'





df=pd.DataFrame()

Hospitalar=["Gram-negative ","Multimodal Analgesia","Postoperative Pain","Surgical Analgesia","Opioid Free","Opioid Sparing","NSAID","COX2",
        "Fast Recovering","ERAS Protocol","Bacterial nosocomial infection","Fungal nosocomial infection","Anaemia","Iron deficiency anemia",
        "Iron deficiency","Fatigue anemia","Tiredness anemia","Hemoglobin anemia","Blood count anemia","Antimicrobial Resistance",
        "Pseudomonas ","KPC bacteria ","Klebsiella","Sepsis","invasive candidiasis","Candidemia","Candidemia in pediatric",
        "Community Acquired Pneumonia","Pneumonia","invasive candidemia","Skin infection","Aspergilosis","Antibiotic Resistance",
        "Aeruginosa ","Coli Bacteria ","Pneumoniae","Aspergillus Reference","Stewardship Antibiotic","Bacteremia",
        "Invasive fungal infection"]

for i in Hospitalar:
    #EXTRAIR METADADOS NOTICIAS 
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        #querystring = {"q":i,"lang":"pt","countries":"BR"}
        querystring = {"q":i,"lang":"en"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
            }
        
        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers, params=querystring).json()

        
        if response['articles']!=[]:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)
            
        else:
            df2=pd.DataFrame()
            df2[["id","title","link","published","sub_articles","source"]] = pd.DataFrame([["", "", "","","",""]])
            
            
        df2.insert(0,'company', i)
        df=pd.concat([df,df2], ignore_index=True, sort=False)
    
    
        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
            }
    except:
        pass
Hospitalar_result=df
Hospitalar_result=Hospitalar_result.rename(columns={'company':'kw'})
Hospitalar_result['categoria'] = 'Hospitalar'




df=pd.DataFrame()

SNC=["Depression","Anxiety","Antidepressant ","Panic Syndrome","MDD","Major Depressive Disorder","Depressed symptoms","Anxious symptoms",
     "Mental Health","Mental Disease","Weaning medicine","Pristiq","Elifore","Desvenlafaxine","Deller","Desve ","Lexapro","Brintellix",
     "Mental disorder","Escitalopran","Venlafaxine","Paroxetine","DULOXETINE","SERTRALINE","MIRTAZAPINE","FLUOXETINE","VORTIOXETINE",
     "FLUVOXAMINE","AGOMELATINE","Bupropion","Sadness Depression","Suicide Depression","Anxiety Depression","Depression symptoms",
     "Pharmacogenetics Depression","pharmacogenetic tests Depression","Comorbity Depression","Pain Depression","Drug interaction antidepressant",
     "Side Effect antidepressant","adverse effect antidepressant","Obesity Depression","Burnout","Pandemic Depression","Covid Depression",
     "TAG anxiety","Antidepressant Switch Depression","Dose Adjustment antidepressant"]

for i in SNC:
    #EXTRAIR METADADOS NOTICIAS 
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        #querystring = {"q":i,"lang":"pt","countries":"BR"}
        querystring = {"q":i,"lang":"en"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
            }
        
        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers, params=querystring).json()

        
        if response['articles']!=[]:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)
            
        else:
            df2=pd.DataFrame()
            df2[["id","title","link","published","sub_articles","source"]] = pd.DataFrame([["", "", "","","",""]])
            
            
        df2.insert(0,'company', i)
        df=pd.concat([df,df2], ignore_index=True, sort=False)
    
    
        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
            }
    except:
        pass

SNC_result=df
SNC_result=SNC_result.rename(columns={'company':'kw'})
SNC_result['categoria'] = 'SNC'




finaldata=pd.concat([Vacinas_result,Hospitalar_result], axis=0)
finaldata=pd.concat([finaldata,DRATTR_result], axis=0)
finaldata=pd.concat([finaldata,DREndocrineCare_result], axis=0)
finaldata=pd.concat([finaldata,DRTransplante_result], axis=0)
finaldata=pd.concat([finaldata,DRHemofilia_result], axis=0)
finaldata=pd.concat([finaldata,DRPipeline_result], axis=0)
finaldata=pd.concat([finaldata,DROutros_result], axis=0)
finaldata=pd.concat([finaldata,SNC_result], axis=0)


finaldata=finaldata.rename(columns={'published_date':'published','_id':'id'})
finaldata1 = finaldata[['kw','id','title','link','published','categoria']]


###
# def convert_date(s):
#     month_dict = {'Jan':'01', 'Feb':'02', 'Mar':'03', 'Apr':'04', 'May':'05', 'Jun':'06',
#                   'Jul':'07', 'Aug':'08', 'Sep':'09', 'Oct':'10', 'Nov':'11', 'Dec':'12'}

#     try:
#         d = s.split(" ")[1]
#         m = month_dict[s.split(" ")[2]]
#         y = s.split(" ")[3]
#     except:
#         return ""

#     return f'{d}-{m}-{y}'

# finaldata1["published"] = finaldata1["published"].apply(convert_date)

import datetime
finaldata1['published'] = pd.to_datetime(finaldata1['published'], errors="coerce", dayfirst=True )



#INSERT NO DB
import pandas as pd
import pandas as pd
import numpy as np
import pymysql
from sqlalchemy import create_engine

host1='pfizerdb.cqxct8aqwlso.us-east-2.rds.amazonaws.com'
port1='3306'
user1='pfizer'
passw1='P!zer2597!'
database1='pfizerdb'

mydb1 = create_engine('mysql+pymysql://' + user1 + ':' + passw1 + '@' + host1 + ':' + str(port1) + '/' + database1 , echo=False)
finaldata1.to_sql(name='google_news_mundo_v2', con=mydb1, if_exists = 'append', index=False)
# Out:
# C:\Users\flavi\AppData\Local\Temp\ipykernel_78020\1879688746.py:552: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   finaldata1['published'] = pd.to_datetime(finaldata1['published'], errors="coerce", dayfirst=True )
# 8895
