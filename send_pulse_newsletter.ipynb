# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText

emails = {"Biossimilares": [
    "andrea.mitelman@pfizer.com",
    "camila.papoy@pfizer.com",
    "fernanda.martins@pfizer.com",
    "fernando.navarro@pfizer.com",
    "fernando.seugling@pfizer.com",
    "jonatas.s.silva@pfizer.com",
    "mariana.pestana@pfizer.com",
    "marta.diez@pfizer.com",
    "miriane.barbosalage@pfizer.com",
    "Rafael.Aznar@pfizer.com",
    "MARIA.FRANCA@pfizer.com",
    "Carolinne.M.Botelho@pfizer.com",
    "ROBERTA.DRAGO2@pfizer.com",
    "DANIELLE.ARAUJOMANO@pfizer.com",
    "caio@orbitdatascience.com"],
    "Cardiologia": [
    "alessandra.ferreira2@pfizer.com",
    "andrea.mitelman@pfizer.com",
    "camila.papoy@pfizer.com",
    "camilla.zuchini@pfizer.com",
    "fernanda.martins@pfizer.com",
    "flavia.m.oliveira@pfizer.com",
    "lucas.feitosa@pfizer.com",
    "miriane.barbosalage@pfizer.com",
    "priscila.guaizzo@pfizer.com",
    "rodrigo.doze@pfizer.com",
    "simone.lima@pfizer.com",
    "vitoria.zanardo@pfizer.com",
    "Rafael.Aznar@pfizer.com",
    "MARIA.FRANCA@pfizer.com",
    "Carolinne.M.Botelho@pfizer.com",
    "ROBERTA.DRAGO2@pfizer.com",
    "DANIELLE.ARAUJOMANO@pfizer.com",
    "caio@orbitdatascience.com",
],
    "Dermatologia": [
    'andre.alterman@pfizer.com',
    'andrea.mitelman@pfizer.com',
    'erick.sagioma@pfizer.com',
    'fernanda.martins@pfizer.com',
    'fernando.navarro@pfizer.com',
    'fernando.seugling@pfizer.com',
    'flavia.m.oliveira@pfizer.com',
    'jonatas.s.silva@pfizer.com',
    'luan.silva@pfizer.com',
    'lucas.feitosa@pfizer.com',
    'mariana.pestana@pfizer.com',
    'miriane.barbosalage@pfizer.com',
    'patricia.a.dreosso@pfizer.com',
    'sergio.mendes@pfizer.com',
    'tiago.santaella@pfizer.com',
    'ursula.duarte@pfizer.com',
    'Rafael.Aznar@pfizer.com',
    'MARIA.FRANCA@pfizer.com',
    'Carolinne.M.Botelho@pfizer.com',
    'ROBERTA.DRAGO2@pfizer.com',
    'DANIELLE.ARAUJOMANO@pfizer.com',
    'caio@orbitdatascience.com',
],
    "DR ": [
    'fernanda.martins@pfizer.com',
    'gabriela.souza@pfizer.com',
    'jonatas.s.silva@pfizer.com',
    'miriane.barbosalage@pfizer.com',
    'patricia.a.dreosso@pfizer.com',
    'rodrigo.doze@pfizer.com',
    'fernanda.martins@pfizer.com',
    'flavia.m.oliveira@pfizer.com',
    'gabriela.souza@pfizer.com',
    'jonatas.s.silva@pfizer.com',
    'miriane.barbosalage@pfizer.com',
    'patricia.a.dreosso@pfizer.com',
    'simone.lima@pfizer.com',
    'fernanda.martins@pfizer.com',
    'gabriela.souza@pfizer.com',
    'isabel.pinheiro@pfizer.com',
    'jonatas.s.silva@pfizer.com',
    'miriane.barbosalage@pfizer.com',
    'simone.lima@pfizer.com',
    'andre.alterman@pfizer.com',
    'andrea.mitelman@pfizer.com',
    'camila.papoy@pfizer.com',
    'fernanda.martins@pfizer.com',
    'fernando.seugling@pfizer.com',
    'gabriela.souza@pfizer.com',
    'isabel.pinheiro@pfizer.com',
    'jonatas.s.silva@pfizer.com',
    'lorena.fehlberg@pfizer.com',
    'lucas.feitosa@pfizer.com',
    'miriane.barbosalage@pfizer.com',
    'simone.lima@pfizer.com',
    'fernanda.martins@pfizer.com',
    'gabriela.souza@pfizer.com',
    'isabel.pinheiro@pfizer.com',
    'jonatas.s.silva@pfizer.com',
    'lorena.fehlberg@pfizer.com',
    'miriane.barbosalage@pfizer.com',
    'simone.lima@pfizer.com',
    'tiago.santaella@pfizer.com',

    'Rafael.Aznar@pfizer.com',
    'MARIA.FRANCA@pfizer.com',
    'Carolinne.M.Botelho@pfizer.com',
    'ROBERTA.DRAGO2@pfizer.com',
    'DANIELLE.ARAUJOMANO@pfizer.com',
],
    "Gastroenterologia": [
    'fernanda.martins@pfizer.com',
    'fernando.navarro@pfizer.com',
    'mariana.pestana@pfizer.com',
    'miriane.barbosalage@pfizer.com',
    'sergio.mendes@pfizer.com',
    'Rafael.Aznar@pfizer.com',
    'MARIA.FRANCA@pfizer.com',
    'Carolinne.M.Botelho@pfizer.com',
    'ROBERTA.DRAGO2@pfizer.com',
    'DANIELLE.ARAUJOMANO@pfizer.com',
    'caio@orbitdatascience.com',
],
    "Hematologia": [
    'andre.nebeldemello@pfizer.com',
    'andrea.mitelman@pfizer.com',
    'camila.papoy@pfizer.com',
    'fernanda.martins@pfizer.com',
    'lorena.fehlberg@pfizer.com',
    'lucas.feitosa@pfizer.com',
    'mariana.martins@pfizer.com',
    'miriane.barbosalage@pfizer.com',
    'patricia.a.dreosso@pfizer.com',
    'rodrigo.doze@pfizer.com',
    'tiago.santaella@pfizer.com',
    'vitoria.zanardo@pfizer.com',
    'Rafael.Aznar@pfizer.com',
    'MARIA.FRANCA@pfizer.com',
    'Carolinne.M.Botelho@pfizer.com',
    'ROBERTA.DRAGO2@pfizer.com',
    'DANIELLE.ARAUJOMANO@pfizer.com',
    'caio@orbitdatascience.com',
],
    "Hospitalar": [
    'alessandra.ferreira2@pfizer.com',
    'andre.o.magalhaes@pfizer.com',
    'andrea.mitelman@pfizer.com',
    'camilla.zuchini@pfizer.com',
    'fernanda.martins@pfizer.com',
    'laurent.baes@pfizer.com',
    'lorena.fehlberg@pfizer.com',
    'lucas.feitosa@pfizer.com',
    'miriane.barbosalage@pfizer.com',
    'natalia.costa@pfizer.com',
    'roberta.drago2@pfizer.com',
    'tiago.santaella@pfizer.com',
    'Rafael.Aznar@pfizer.com',
    'MARIA.FRANCA@pfizer.com',
    'Carolinne.M.Botelho@pfizer.com',
    'ROBERTA.DRAGO2@pfizer.com',
    'DANIELLE.ARAUJOMANO@pfizer.com',
    'caio@orbitdatascience.com',
],
    "Oncologia": [
    'andre.alterman@pfizer.com',
    'andre.nebeldemello@pfizer.com',
    'andrea.mitelman@pfizer.com',
    'fernanda.martins@pfizer.com',
    'flavia.m.oliveira@pfizer.com',
    'helena.junqueira@pfizer.com',
    'ilana.osmo@pfizer.com',
    'jonatas.s.silva@pfizer.com',
    'mariana.martins@pfizer.com',
    'marta.diez@pfizer.com',
    'miriane.barbosalage@pfizer.com',
    'natalia.costa@pfizer.com',
    'patricia.a.dreosso@pfizer.com',
    'rodrigo.doze@pfizer.com',
    'tiago.santaella@pfizer.com',
    'andre.nebeldemello@pfizer.com',
    'helena.junqueira@pfizer.com',
    'ilana.osmo@pfizer.com',
    'jonatas.s.silva@pfizer.com',
    'lucas.feitosa@pfizer.com',
    'miriane.barbosalage@pfizer.com',
    'natalia.costa@pfizer.com',
    'tiago.santaella@pfizer.com',
    'andre.nebeldemello@pfizer.com',
    'fernanda.martins@pfizer.com',
    'fernando.seugling@pfizer.com',
    'ilana.osmo@pfizer.com',
    'jonatas.s.silva@pfizer.com',
    'luan.silva@pfizer.com',
    'miriane.barbosalage@pfizer.com',
    'natalia.costa@pfizer.com',
    'tiago.santaella@pfizer.com',
    'andre.nebeldemello@pfizer.com',
    'fernanda.martins@pfizer.com',
    'helena.junqueira@pfizer.com',
    'ilana.osmo@pfizer.com',
    'jonatas.s.silva@pfizer.com',
    'miriane.barbosalage@pfizer.com',
    'natalia.costa@pfizer.com',
    'andre.nebeldemello@pfizer.com',
    'fernanda.martins@pfizer.com',
    'ilana.osmo@pfizer.com',
    'jonatas.s.silva@pfizer.com',
    'miriane.barbosalage@pfizer.com',
    'natalia.costa@pfizer.com',
    'tiago.santaella@pfizer.com',
    'Rafael.Aznar@pfizer.com',
    'MARIA.FRANCA@pfizer.com',
    'Carolinne.M.Botelho@pfizer.com',
    'ROBERTA.DRAGO2@pfizer.com',
    'DANIELLE.ARAUJOMANO@pfizer.com',
    'caio@orbitdatascience.com',
],
    "Pfizer": [
    'alessandra.ferreira2@pfizer.com',
    'andre.alterman@pfizer.com',
    'andre.nebeldemello@pfizer.com',
    'andrea.mitelman@pfizer.com',
    'bianca.almeida@pfizer.com',
    'camila.papoy@pfizer.com',
    'camilla.zuchini@pfizer.com',
    'carlos.vitti@pfizer.com',
    'fernanda.martins@pfizer.com',
    'fernando.seugling@pfizer.com',
    'flavia.m.oliveira@pfizer.com',
    'gabriela.souza@pfizer.com',
    'gustavo.sanches@pfizer.com',
    'helena.junqueira@pfizer.com',
    'ilana.osmo@pfizer.com',
    'isabel.pinheiro@pfizer.com',
    'jonatas.s.silva@pfizer.com',
    'lorena.fehlberg@pfizer.com',
    'luan.silva@pfizer.com',
    'lucas.feitosa@pfizer.com',
    'mariana.martins@pfizer.com',
    'marta.diez@pfizer.com',
    'miriane.barbosalage@pfizer.com',
    'natalia.costa@pfizer.com',
    'priscila.guaizzo@pfizer.com',
    'roberta.drago2@pfizer.com',
    'sergio.mendes@pfizer.com',
    'simone.lima@pfizer.com',
    'tiago.santaella@pfizer.com',
    'ursula.duarte@pfizer.com',
    'vitoria.zanardo@pfizer.com',
    'Rafael.Aznar@pfizer.com',
    'MARIA.FRANCA@pfizer.com',
    'Carolinne.M.Botelho@pfizer.com',
    'ROBERTA.DRAGO2@pfizer.com',
    'DANIELLE.ARAUJOMANO@pfizer.com',
    'caio@orbitdatascience.com',
],
    "Reumatologia": [
    'camilla.zuchini@pfizer.com',
    'fernanda.martins@pfizer.com',
    'fernando.navarro@pfizer.com',
    'flavia.m.oliveira@pfizer.com',
    'jonatas.s.silva@pfizer.com',
    'mariana.pestana@pfizer.com',
    'miriane.barbosalage@pfizer.com',
    'patricia.a.dreosso@pfizer.com',
    'sergio.mendes@pfizer.com',
    'Rafael.Aznar@pfizer.com',
    'MARIA.FRANCA@pfizer.com',
    'Carolinne.M.Botelho@pfizer.com',
    'ROBERTA.DRAGO2@pfizer.com',
    'DANIELLE.ARAUJOMANO@pfizer.com',
    'caio@orbitdatascience.com',
],
    "SNC": [
    'alessandra.ferreira2@pfizer.com',
    'anaflavia.gindro@pfizer.com',
    'andrea.mitelman@pfizer.com',
    'bianca.almeida@pfizer.com',
    'camila.papoy@pfizer.com',
    'fernanda.martins@pfizer.com',
    'flavia.m.oliveira@pfizer.com',
    'miriane.barbosalage@pfizer.com',
    'natalia.costa@pfizer.com',
    'priscila.guaizzo@pfizer.com',
    'Rafael.Aznar@pfizer.com',
    'MARIA.FRANCA@pfizer.com',
    'Carolinne.M.Botelho@pfizer.com',
    'ROBERTA.DRAGO2@pfizer.com',
    'DANIELLE.ARAUJOMANO@pfizer.com',
    'caio@orbitdatascience.com',
],
    "Vacinas": [
    'alessandra.ferreira2@pfizer.com',
    'andre.alterman@pfizer.com',
    'andre.nebeldemello@pfizer.com',
    'andrea.mitelman@pfizer.com',
    'carlos.vitti@pfizer.com',
    'fernanda.martins@pfizer.com',
    'fernando.navarro@pfizer.com',
    'flavia.m.oliveira@pfizer.com',
    'gustavo.sanches@pfizer.com',
    'jonatas.s.silva@pfizer.com',
    'lorena.fehlberg@pfizer.com',
    'lucas.feitosa@pfizer.com',
    'marta.diez@pfizer.com',
    'miriane.barbosalage@pfizer.com',
    'natalia.costa@pfizer.com',
    'nayara.vieirapereira@pfizer.com',
    'patricia.a.dreosso@pfizer.com',
    'tiago.santaella@pfizer.com',
    'ursula.duarte@pfizer.com',
    'Rafael.Aznar@pfizer.com',
    'MARIA.FRANCA@pfizer.com',
    'Carolinne.M.Botelho@pfizer.com',
    'ROBERTA.DRAGO2@pfizer.com',
    'DANIELLE.ARAUJOMANO@pfizer.com',
    'caio@orbitdatascience.com',
]}

keys = ["Biossimilares", "Cardiologia", "Dermatologia", "DR ", "Gastroenterologia",
        "Hematologia", "Hospitalar", "Oncologia", "Pfizer", "Reumatologia", "SNC", "Vacinas"]

def sendEmail(from_email,email_password,  to_email, assunto, cc, cco, mensagem ): # type: ignore
    
    # create message object instance
    msg = MIMEMultipart('alternative')
    msg['From'] = from_email
    msg['To'] = to_email
    msg['Subject'] = assunto
    msg["Bcc"] = cco


    # attach HTML content to message
    html_part = MIMEText(mensagem, 'html')
    msg.attach(html_part)

    # send the message via SMTP server
    with smtplib.SMTP('smtp.gmail.com', 587) as server:
        server.starttls()
        server.login(from_email, email_password)
        #server.sendmail(my_email, to_email, msg.as_string())
        server.send_message(msg)
        server.quit()
        

#my_email = "flaviotome5@gmail.com"
#my_password = "osfernflgrthocld"
my_email = "pfizer.pulse@orbitdatascience.com"
my_password = "aaptbbmrlirbgyoe"
to_email = "pfizer.pulse@orbitdatascience.com"
subject = ""
cc = ""
cco = "flaviotome5@gmail.com,operacoes@orbitdatascience.com,flavio.tome@orbitdatascience.com"

for k in keys:
    with open("html/{}.html".format(k),"rb") as fp:
        # Create a text/plain message
        print("sending {} to...".format(k))
        
        endereco_final = ''
        for email in emails[k]:
            endereco_final = email + "," + endereco_final        
        print(endereco_final)

        html = fp.read().decode('utf-8')
        subject = "Pfizer Pulse Newsletter: {}".format(k)
        sendEmail(my_email, my_password,  to_email, subject, cc, endereco_final, html)
# Out:
# sending Biossimilares to...
# caio@orbitdatascience.com,DANIELLE.ARAUJOMANO@pfizer.com,ROBERTA.DRAGO2@pfizer.com,Carolinne.M.Botelho@pfizer.com,MARIA.FRANCA@pfizer.com,Rafael.Aznar@pfizer.com,miriane.barbosalage@pfizer.com,marta.diez@pfizer.com,mariana.pestana@pfizer.com,jonatas.s.silva@pfizer.com,fernando.seugling@pfizer.com,fernando.navarro@pfizer.com,fernanda.martins@pfizer.com,camila.papoy@pfizer.com,andrea.mitelman@pfizer.com,
# sending Cardiologia to...
# caio@orbitdatascience.com,DANIELLE.ARAUJOMANO@pfizer.com,ROBERTA.DRAGO2@pfizer.com,Carolinne.M.Botelho@pfizer.com,MARIA.FRANCA@pfizer.com,Rafael.Aznar@pfizer.com,vitoria.zanardo@pfizer.com,simone.lima@pfizer.com,rodrigo.doze@pfizer.com,priscila.guaizzo@pfizer.com,miriane.barbosalage@pfizer.com,lucas.feitosa@pfizer.com,flavia.m.oliveira@pfizer.com,fernanda.martins@pfizer.com,camilla.zuchini@pfizer.com,camila.papoy@pfizer.com,andrea.mitelman@pfizer.com,alessandra.ferreira2@pfizer.com,
# sending Dermatologia to...
# ...

# %%
for k in keys:
    endereco_final = ''
    for email in emails[k]:
        endereco_final = email + "," + endereco_final
    print(k+" : ")
    print(endereco_final)
# Out:
# Biossimilares :
# caio@orbitdatascience.com,DANIELLE.ARAUJOMANO@pfizer.com,ROBERTA.DRAGO2@pfizer.com,Carolinne.M.Botelho@pfizer.com,MARIA.FRANCA@pfizer.com,Rafael.Aznar@pfizer.com,miriane.barbosalage@pfizer.com,marta.diez@pfizer.com,mariana.pestana@pfizer.com,jonatas.s.silva@pfizer.com,fernando.seugling@pfizer.com,fernando.navarro@pfizer.com,fernanda.martins@pfizer.com,camila.papoy@pfizer.com,andrea.mitelman@pfizer.com,
# Cardiologia :
# caio@orbitdatascience.com,DANIELLE.ARAUJOMANO@pfizer.com,ROBERTA.DRAGO2@pfizer.com,Carolinne.M.Botelho@pfizer.com,MARIA.FRANCA@pfizer.com,Rafael.Aznar@pfizer.com,vitoria.zanardo@pfizer.com,simone.lima@pfizer.com,rodrigo.doze@pfizer.com,priscila.guaizzo@pfizer.com,miriane.barbosalage@pfizer.com,lucas.feitosa@pfizer.com,flavia.m.oliveira@pfizer.com,fernanda.martins@pfizer.com,camilla.zuchini@pfizer.com,camila.papoy@pfizer.com,andrea.mitelman@pfizer.com,alessandra.ferreira2@pfizer.com,
# Dermatologia :
# ...
