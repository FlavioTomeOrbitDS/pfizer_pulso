# %%
import requests
import pandas as pd
import requests
import pandas as pd
from sqlalchemy import create_engine

# %%
df = pd.DataFrame()

Dermato = ["Adalimumabe", "Alopecia Areata", "Alto Custo", "Anticorpo Antidroga", "Anticorpo Antidroga", "Anticorpo Antidroga Neutralizante",
           "Artrite Psoriásica", "Artrite Psoriática", "baricitinibe", "Biológicos", "Biossimilar", "Biossimilares", "Biossimilaridade",
           "Dermatite", "Dermatite Atópica", "Doenças imunomediadas", "Doenças Inflamatórias", "Etanercepte", "inibidor da JAK", "Psoríase",
           "Psoríase em Placas", "secuquinumabe", "Terapia biológica", "Tofacitinibe", "Tuberculose", "upadacitinibe", "Ustequinumabe", "Vitiligo",
           "Dermatite Atópica", "SBD", "Hidradenite Supurativa", "Dupilumabe", "Dupixent", "Rinvoq", "Olumiant", "Sociedade Brasileira de Dermatologia",
           "Paulo Criado", "Roberto Takaoka", "Valeria Aoki", "Sociedade Brasileira de Alegia e Imunologia", "ASBAI", "Eczema",
           "Dermatite de contato", "Uticária", "Coceira ", "Pele sensível", "Prurido", "Depressão", "Absenteísmo", "AAD", "EADV ",
           "terapia sistemica", "JADE Pfizer", "Abrocinitibe"]

for i in Dermato:
    #EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q": "Dermatologia "+ i, "lang": "pt", "countries": "BR"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass

Dermato_result = df
Dermato_result = Dermato_result.rename(columns={'company': 'kw'})
Dermato_result['categoria'] = 'Dermatologia'

# %%
Dermato_result[['title', 'kw', 'published_date','link']].to_excel('./exported/dermato_revisado_dermatologia.xlsx')

# %%
df = pd.DataFrame()

Reumato = ["Reumatologia abatacepte", "ACR - Colégio Americano de Reumatologia", "Reumatologia Adalimumabe", "Reumatologia Alto Custo", "Reumatologia Anticorpo Antidroga", "Reumatologia Anticorpo Antidroga Neutralizante",
           "Reumatologia Anticorpo Monoclonal", "Artrite", "Artrite Idiopática Juvenil", "Artrite Idiopática Juvenil Poliarticular", "Artrite Psoriásica",
           "Artrite Psoriática", "Artrite relacionada a Entesite", "Artrite Reumatoide", "Reumatologia baricitinibe", "Reumatologia Biológicos", "Reumatologia Biossimilar", "Reumatologia Biossimilares",
           "Reumatologia Biossimilaridade", "Reumatologia certolizumabe", "Congresso Brasileiro de Reumatologia", "Reumatologia Cristiano Campanholo", "Reumatologia Doenças imunomediadas",
           "Reumatologia Doenças Inflamatórias", '"Dor articular"', "Reumatologia Espondilite Anquilosante", "Reumatologia Espondiloartrite Axial não Radiográfica", "Reumatologia Etanercepte",
           "Liga Europeia contra o Reumatismo", "EULAR", "Reumatologia Fator de Necrose tumoral", "Reumatologia Herpes Zoster", "Reumatologia Infliximabe", "Reumatologia inibidor da JAK",
           "Reumatologia Karina Bonfiglioli", "Reumatologia Licia Mota", "LME", "Lombalgia", "Reumatologia Necrose tumoral", "Reumatologia Ricardo Xavier", "Reumatologia rituximabe", "Reumatologia Sebastião Radominski",
           "secuquinumabe", "Sociedade Brasileira de Reumatologia", "Reumatologia Terapia biológica", "Reumatologia tocilizumabe", "Reumatologia Tofacitinibe", "Trombose", "Reumatologia Tuberculose",
           "Reumatologia Ultra-som articular", "Reumatologia upadacitinibe", "Reumatologia Ustequinumabe", "Reumatologia Uveíte", "Reumatologia Uveíte Pediátrica", "Reumatologia Valderilio Feijó Azevedo", "Reumatologia Vedolizumabe",
           "Reumatologia upadacitinibe", "Reumatologia Dupilumabe", "Reumatologia Rinvoq", "Reumatologia Olumiant"]

for i in Reumato:
    #EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q":i, "lang": "pt", "countries": "BR"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass

Reumato_result = df
Reumato_result = Reumato_result.rename(columns={'company': 'kw'})
Reumato_result['categoria'] = 'Reumatologia'

# %%
Reumato_result[['title', 'kw', 'published_date','link']].to_excel('./exported/reumato_revisado_reumatologia_kw_especifica.xlsx')

# %%
df = pd.DataFrame()

Gastro = ["gastroenterologia Adalimumabe", "gastroenterologia Anticorpo Antidroga", "Anti-Neutralizing Drug Antibody", "gastroenterologia Anticorpo Monoclonal", "gastroenterologia Biológico", "gastroenterologia Biossimilar",
          "gastroenterologia Biossimilares", "gastroenterologia Biossimilaridade", "gastroenterologia Cicatrização de mucosa", "Colite", "Colite Ulcerativa", "Colonoscopia", "Coloproctologia",
          "Crohn", "Diarreia sintoma", "gastroenterologia DII", "Doença de Crohn", "Doença de Crohn Fistulizante", "Doença Gastrintestinal",
          "Doença Inflamatória Intestinal", "Filgotinibe", "Gastroenterologia", "Manifestações extraintestinais", "gastroenterologia PANCCO", "gastroenterologia Paulo Kotze",
          "Retocolite", "Retocolite Ulcerativa", "gastroenterologia SEBRADII", "Ultra-som intestinal", "gastroenterologia terapia biológica", "Tofacitinibe", "Trombose", "Tuberculose",
          "UEGW", "gastroenterologia Doenças imunomediadas", "gastroenterologia Doenças inflamatórias", "gastroenterologia ECCO-IBD", "gastroenterologia Infliximabe", "gastroenterologia IOIBD", "gastroenterologia JAK", "gastroenterologia LME"]

for i in Gastro:
    #EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q": i, "lang": "pt", "countries": "BR"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass

Gastro_result = df
Gastro_result = Gastro_result.rename(columns={'company': 'kw'})
Gastro_result['categoria'] = 'Gastroenterologia'

# %%
Gastro_result[['title', 'kw', 'published_date', 'link']].to_excel(
    './exported/gastro_revisado.xlsx')

# %%
df = pd.DataFrame()

Onco = ["Oncologia", "Onco", "Onco-Hemato", "Câncer", "Cancerígeno", "Cancerígena", "Carcinoma", "Neoplasia", "Tumor", "Imunoterapia", "Quimioterapia",
        "Hormonioterapia", "Oncologia Terapia Alvo", "Oncologia Transplante", "Oncologia Medula Óssea", "Metástase", "Mestastático", "Células Anormais", "Nódulo", "Primeira Linha câncer",
        "Segunda Linha câncer", "Terceira Linha câncer", "Estágio I câncer", "Estágio II câncer", "Estágio III câncer", "Estágio IV câncer", "Oncologia INCA",
        "Oncologia ICESP", '"Hospital do Amor"', "AC Camargo", "Quinase", "Oncologia Sobrevida", "Monoterapia", "Sobrevida Livre de Progressão", "SLP câncer"]

for i in Onco:
    #EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q": i, "lang": "pt", "countries": "BR"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass

Onco_result = df
Onco_result = Onco_result.rename(columns={'company': 'kw'})
Onco_result['categoria'] = 'Oncologia'

# %%
Onco_result[['title', 'kw', 'published_date', 'link']].to_excel(
    './exported/onco_revisado.xlsx')

# %%
df = pd.DataFrame()

Hemato = ["Leucemia", "Leucemia Aguda", "Mielóide", "Linfóide", "LMA câncer", "LMC câncer", "LLA câncer", "LLC câncer", "Mieloma Múltiplo",
          "Leucemia Linfoblastica Aguda", "CD33 câncer", "anti-CD33 câncer", "ALFA-0701 câncer", "CD19 câncer", "CD22 câncer", "INO-VATE câncer",
          "Mieloide", "Leucemia linfoblástica aguda", "inotuzumabe Ozogamicina", "cromossomo philadelphia negativo", "DRM câncer", "Blinatumomabe",
          "Gentuzumabe", "InO câncer", "Blina câncer", "GO câncer", "LLA Ph+ câncer", "TCTH câncer", "CAR-T câncer", "BMT câncer", "Elranatamab",
          "Leucemia Mieloide Aguda", "Bosutinibe", "Dasatinibe", "Nilotinibe", "inotuzumabe", "Hemofilia"]

for i in Hemato:
    #EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q": i, "lang": "pt", "countries": "BR"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass

Hemato_result = df
Hemato_result = Hemato_result.rename(columns={'company': 'kw'})
Hemato_result['categoria'] = 'Hematologia'

Hemato_result.drop_duplicates(subset=['title'], inplace=True)

# %%
Hemato_result[['title', 'kw', 'published_date', 'link']].to_excel(
    './exported/hematologia_droped_duplicates.xlsx')

# %%
df = pd.DataFrame()

Biossimilares = ["Biossimilar", "Biossimilaridade", "Imunogenicidade", "Intercambialidade", "Biossimilar Substituição automática", "Biossimilaridade Substituição automática", "Switch Biossimilar", "Cross Switch Biossimilar",
                 "Switch reverso Biossimilar", "Múltiplos switches Biossimilar", "Originador Biossimilar", "Referência Biossimilar", "DMARDS", "Biossimilar Biológicos",
                 "Rituximabe", "Trastuzumabe", "Bevacizumabe", "Libbs", "Sandoz", "Amgen", "Celltrion", "SOBRAFO Biossimilar", "FLAB Biossimilar",
                 "Valderilio Feijó Azevedo Biossimilar", "Terapia biológica", "intercambiabilidade biossimilar", "Infliximabe", "Adalimumabe"]

for i in Biossimilares:
    #EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q": i, "lang": "pt", "countries": "BR"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass

Biossimilares_result = df
Biossimilares_result = Biossimilares_result.rename(columns={'company': 'kw'})
Biossimilares_result['categoria'] = 'Biossimilares'
Biossimilares_result.drop_duplicates(subset=['title'], inplace=True)

# %%
Biossimilares_result[['title', 'kw', 'published_date', 'link']].to_excel(
    './exported/biossim_droped_duplicates.xlsx')

# %%
df = pd.DataFrame()

OncologiaMama = ["Câncer de Mama", "Palbociclibe", "Abemaciclibe", "Ribociclibe", "Examestano", "Talazoparibe", "CDK câncer mama", "iCDK câncer mama",
                 "Ciclina câncer mama", "HER2 câncer mama", "HR+ câncer mama", "HR- câncer mama", "HER2+ câncer mama", "RE+ câncer mama",
                 "RE- câncer mama", "BRCA1 câncer mama", "BRCA2 câncer mama", "CDK 4/6 câncer mama", "CMM câncer mama",
                 "receptor de fator de crescimento epidérmico humano 2", "Câncer de Mama Metastático ", "Câncer de Mama Avançado",
                 "Inibidor de Ciclina", "PALOMA-1 câncer mama", "PALOMA-2 câncer mama", "PALOMA-3 câncer mama", "IRIS câncer mama",
                 "FLATIRON câncer mama", "PALOMAGE câncer mama", "Receptor de estrogênio", "Receptor hormonal ", "Ciclina D1", "PARPi",
                 "Inibidor de PARP", "EMBRACA", "TALAPRO-1 ", "Câncer de mama localmente avançado", "mutação germinativa no BRCA", "Trastuzumabe"]

for i in OncologiaMama:
    #EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q": i, "lang": "pt", "countries": "BR"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass

OncologiaMama_result = df
OncologiaMama_result = OncologiaMama_result.rename(columns={'company': 'kw'})
OncologiaMama_result['categoria'] = 'Oncologia(Mama)'
OncologiaMama_result.drop_duplicates(subset=['title'], inplace=True)

# %%
OncologiaMama_result[['title', 'kw', 'published_date', 'link']].to_excel(
    './exported/oncologia_mama_revisado.xlsx')

# %%
df = pd.DataFrame()

Pfizer = ["Pfizer", "Pfaizer", "Faizer", "Pifizer"]

for i in Pfizer:
    #EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q": i, "lang": "pt", "countries": "BR"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass

Pfizer_result = df
Pfizer_result = Pfizer_result.rename(columns={'company': 'kw'})
Pfizer_result['categoria'] = 'Pfizer'
Pfizer_result.drop_duplicates(subset=['title'], inplace=True)

# %%
Pfizer_result[['title', 'kw', 'published_date', 'link']].to_excel(
    './exported/pfizer_revisado.xlsx')

# %%
df=pd.DataFrame()

DRATTR=["amiloidose","amiloidose","Vyndaqel","Vyndamax","Onpattro","patisirana","Tegsedi","inotersena","vutrisirana","PAF Polineuropatia Amiloidótica Familiar",
        "polineuropatia amiloidótica familiar","amiloidose cardíaca","ATTR","insuficiência cardíaca","ICFEp","QSART","Sudoscan",
        "Protocolo Insuficiência Cardíaca","wATTR","hATTR","síndrome túnel do carpo","Amiloidose associada à transtirretina",
        "Hipertrofia ventricular","Cardiomiopatia ","ATTR-CM","ATTR-PN","Cardiomiopatia amiloide","Cardiomiopatia amiloidótica por transtirretina",
        "CAF Cardiomiopatia Amiloidotica Familiar","Cardiomiopatia amiloide familiar","ATTRwt","ATTRh","ATTRm","ATTRv","Val30Met","Val50Met","V30M",
        "V50M","Val122Ile","Val142Ile","V122I","V142I","Cardiomiopatia restritiva","Fração de ejeção preservada","ATTR selvagem","ATTR hereditária",
        "Mutações TTR","Acoramidis","AG-10","Estabilizador TTR","Silenciador gênico TTR","ABPAR","Sequenciamento TTR","Teste genético ATTR",
        "sintomas e sinais PAF","sintomas e sinas ATTR-CM","doença hereditária"]

for i in DRATTR:
    #EXTRAIR METADADOS NOTICIAS 
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q":i,"lang":"pt","countries":"BR"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
            }
        
        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers, params=querystring).json()

        
        if response['articles']!=[]:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)
            
        else:
            df2=pd.DataFrame()
            df2[["id","title","link","published","sub_articles","source"]] = pd.DataFrame([["", "", "","","",""]])
            
            
        df2.insert(0,'company', i)
        df=pd.concat([df,df2], ignore_index=True, sort=False)
    
    
        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
            }
    except:
        pass

DRATTR_result=df
DRATTR_result=df
DRATTR_result=DRATTR_result.rename(columns={'company':'kw'})
DRATTR_result['categoria'] = 'ATTR'
DRATTR_result.drop_duplicates(subset=['title'], inplace=True)

# %%
DRATTR_result[['title', 'kw', 'published_date', 'link']].to_excel(
    './exported/ATTR_revisado.xlsx')

# %%
df = pd.DataFrame()
Hospitalar = ["Gram-negativo", "Analgesia multimodal", "Dor Pós Operatória", "Analgesia cirúrgica", "Analgesia cirúrgica", "Hospitalar Sem Opioides",
              "Poupar Opioide", "Hospitalar_result AINE", "Hospitalar_result COX2", 'Hospitalar "Rápida Recuperação"', "Hospitalar Protocolo ERAS", 
              "Hospitalar Infecção bacteriana", "Hospitalar Infecção fúngica", "Anemia",
              "Anemia Ferropriva", '"Deficiência de ferro"', "Fadiga anemia", "Cansaço anemia", "Hemoglobina anemia", "Hemograma anemia",
              "Hospitalar Resistência Bacteriana", "Pseudomonas", "KPC bacteria", "Klebsiella", "Sepse", "Candidíase invasiva", "Candidemia",
              "Candidemia na Pediatria", "Pneumonia Adquirida em comunidade", "Pneumonia", "Candidemia invasiva", "Infecção de Pele",
              "Aspergilose", "Hospitalar Resistência a antibióticos ", "Aeruginosa ", "Coli bacteria", "Pneumoniae", "Referencia Aspergilose",
              "Stewardship antibiótico", "Bacteremia", "Infecção fúngica invasiva"]

for i in Hospitalar:
    #EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q": i, "lang": "pt", "countries": "BR"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass

Hospitalar_result = df
Hospitalar_result = Hospitalar_result.rename(columns={'company': 'kw'})
Hospitalar_result['categoria'] = 'Hospitalar'
Hospitalar_result.drop_duplicates(subset=['title'], inplace=True)

# %%
Hospitalar_result[['title', 'kw', 'published_date', 'link']].to_excel(
    './exported/Hospitalar_revisado.xlsx')

# %%
import numpy as np
import datetime
import requests
import pandas as pd
import requests
import time
import pandas as pd
import pymysql
from sqlalchemy import create_engine



from datetime import datetime, timedelta
today = datetime.today()
yesterday = datetime.today() - timedelta(days=1)


df = pd.DataFrame()

DRATTR = ["amiloidose", "amiloidose", "Vyndaqel", "Vyndamax", "Onpattro", "patisirana", "Tegsedi", "inotersena", "vutrisirana", "PAF Polineuropatia Amiloidótica Familiar",
          "polineuropatia amiloidótica familiar", "amiloidose cardíaca", "ATTR", "insuficiência cardíaca", "ICFEp", "QSART", "Sudoscan",
          "Protocolo Insuficiência Cardíaca", "wATTR", "hATTR", "síndrome túnel do carpo", "Amiloidose associada à transtirretina",
          "Hipertrofia ventricular", "Cardiomiopatia ", "ATTR-CM", "ATTR-PN", "Cardiomiopatia amiloide", "Cardiomiopatia amiloidótica por transtirretina",
          "CAF Cardiomiopatia Amiloidotica Familiar", "Cardiomiopatia amiloide familiar", "ATTRwt", "ATTRh", "ATTRm", "ATTRv", "Val30Met", "Val50Met", "V30M",
          "V50M", "Val122Ile", "Val142Ile", "V122I", "V142I", "Cardiomiopatia restritiva", "Fração de ejeção preservada", "ATTR selvagem", "ATTR hereditária",
          "Mutações TTR", "Acoramidis", "AG-10", "Estabilizador TTR", "Silenciador gênico TTR", "ABPAR", "Sequenciamento TTR", "Teste genético ATTR",
          "sintomas e sinais PAF", "sintomas e sinas ATTR-CM", "doença hereditária"]

for i in DRATTR:
    #EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q": i, "lang": "pt",
                       "countries": "BR", "from": yesterday, "to": today}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass

DRATTR_result = df
DRATTR_result = df
DRATTR_result = DRATTR_result.rename(columns={'company': 'kw'})
DRATTR_result['categoria'] = 'ATTR'


df = pd.DataFrame()

DREndocrineCare = ["somatropina", "hormônio GH", "GH longa duração", "Prader Willi", "Síndrome Turner", "BEI baixa estatura", "Baixa Estatura Idiopática",
                   "disturbio de crescimento crianças", "DGH", "Norditropin", "Saizen", "hormotrop", "Omnitrope", "endócrino-pediatra", "Endoped", "Crescimento infantil",
                   "Endocrinologia Pediátrica", "Pediatria crescimento infantil", "Hormônio do crescimento", "Desenvolvimento infantil altura crescimento",
                   "Curvas crescimento", "Velocidade crescimento", "PIG crescimento crianças", "Pequeno para idade gestacional", "Deficiência hormônio crescimento",
                   "Estirão crescimento", "Segurança GH crescimento", "Investigação baixa estatura crianças", "Exoma crescimento", "Cariótipo síndrome Turner",
                   "Estudo genético crianças baixa estatura", "Fórmula de Tanner", "pescoço alado síndrome Turner", "IGF-1 crescimento infantil",
                   "IGFBP-3 crescimento infantil", "exames genéticos baixa estatura", "metilação DNA síndrome Prader-Willi",
                   "Hipotonia neonatal síndrome Prader-Willi"]

for i in DREndocrineCare:
    #EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q": i, "lang": "pt",
                       "countries": "BR", "from": yesterday, "to": today}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass

DREndocrineCare_result = df
DREndocrineCare_result = df
DREndocrineCare_result = DREndocrineCare_result.rename(
    columns={'company': 'kw'})
DREndocrineCare_result['categoria'] = 'EndocrineCare'


df = pd.DataFrame()

DRTransplante = ["imTOR", "rapamicina", "Rapamune", "transplante renal", "paciente transplantado", "ABTO", "transplante de orgãos",
                 "everolimo", "Certican", "Protocolo Imunossupressão rim", "Imunossupressão rim", "rim transplante", "perda do rim", "função renal",
                 "hemodiálise", "lista de transplante rim ", "PCDT de transplantes ", "Associação Brasileira de Transplanstes de orgãos",
                 "Função Tardia do Rim", "Micofenolato", "Prednisona", "Ciclosporina", "Azatioprina", "LAM doença pulmonar", "Linfangioleiomiomatose",
                 "Enxerto rim", "Infecções virais transplante", "proteinúria transplante", "rejeiçao do órgão transplante", "Poliomavírus", "CMV",
                 "Citomegalovírus", "Exame PCR", "Nivel sanguineo do imunossupressor", "Dosagem sanguínea do imunossupressor", "BK vírus",
                 "filtração glomerular", "protocolos clínicos e diretrizes terapêuticas transplante", "Micofenolato de sodio"]

for i in DRTransplante:
    #EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q": i, "lang": "pt",
                       "countries": "BR", "from": yesterday, "to": today}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass

DRTransplante_result = df
DRTransplante_result = df
DRTransplante_result = DRTransplante_result.rename(columns={'company': 'kw'})
DRTransplante_result['categoria'] = 'Transplante'


df = pd.DataFrame()

DRHemofilia = ["Fator VIII hemofilia", "Fator Recombinante hemofilia", "Fator plasmático hemofilia", "Hemofílico",
               "BenefiX", "alfanonacogue", "Xyntha", "alfamoroctocogue", "Elprolix", "alfaeftrenonacogue", "Rixubis", "gamanonacogue", "sangramento hemofilia"]

for i in DRHemofilia:
    #EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q": i, "lang": "pt",
                       "countries": "BR", "from": yesterday, "to": today}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass

DRHemofilia_result = df
DRHemofilia_result = df
DRHemofilia_result = DRHemofilia_result.rename(columns={'company': 'kw'})
DRHemofilia_result['categoria'] = 'Hemofilia'


df = pd.DataFrame()

DRPipeline = ["terapia gênica", "Exondys 51", "eteplirsen", "Vyondys", "golodirsen", "Vyondys 53", "Amondys 45", "casimersen",
              "zolgensma", "onasemnogeno abeparvoveque", "Luxturna", "voretigene neparvoveque", "Spinraza", "nusinersena", "Soliris", "eculizumabe",
              "somatrogon", "Duchenne", "Doenças raras", "Teste genético"]

for i in DRPipeline:
    #EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q": i, "lang": "pt",
                       "countries": "BR", "from": yesterday, "to": today}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass

DRPipeline_result = df
DRPipeline_result = df
DRPipeline_result = DRPipeline_result.rename(columns={'company': 'kw'})
DRPipeline_result['categoria'] = 'Terapia Gênica'


df = pd.DataFrame()

DROutros = ["Congresso Brasileiro Pediátrico de Endocrinologia e Metabologia",
            "Congresso Brasileiro de Neurologia", "Congresso Brasileiro de Cardiologia", "Congresso Brasileiro de Neurologia",
            "Congresso Brasileiro de Cardiologia", "Congresso Brasileiro de Genética Médica", "Congresso Brasileiro de Medicina Nuclear",
            "Departamento de Insuficiência Cardíaca", "sociedade de cardiologia do estado de são paulo",
            "Congresso Brasileiro de Endocrinologia e Metabologia", "Congresso Paulista de Endocrinologia e Metabologia",
            "Congresso Europeu de Transplanstes ", "Congresso Brasileiro de Transplantes", "Associação Brasileira de Transplante de Órgãos",
            "Congresso Brasileiro de Transplanstes de Orgãos", "Congresso Mineiro de Transplantes"]

for i in DROutros:
    #EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q": i, "lang": "pt",
                       "countries": "BR", "from": yesterday, "to": today}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass

DROutros_result = df
DROutros_result = df
DROutros_result = DROutros_result.rename(columns={'company': 'kw'})
DROutros_result['categoria'] = 'Outros'


finaldata = pd.concat([DRATTR_result], axis=0)
finaldata = pd.concat([finaldata, DREndocrineCare_result], axis=0)
finaldata = pd.concat([finaldata, DRTransplante_result], axis=0)
finaldata = pd.concat([finaldata, DRHemofilia_result], axis=0)
finaldata = pd.concat([finaldata, DRPipeline_result], axis=0)
finaldata = pd.concat([finaldata, DROutros_result], axis=0)
finaldata = pd.concat([finaldata, SNC_result], axis=0)


finaldata = finaldata.rename(
    columns={'published_date': 'published', '_id': 'id'})
finaldata1 = finaldata[['kw', 'id', 'title', 'link', 'published', 'categoria']]


###
# def convert_date(s):
#     month_dict = {'Jan':'01', 'Feb':'02', 'Mar':'03', 'Apr':'04', 'May':'05', 'Jun':'06',
#                   'Jul':'07', 'Aug':'08', 'Sep':'09', 'Oct':'10', 'Nov':'11', 'Dec':'12'}

#     try:
#         d = s.split(" ")[1]
#         m = month_dict[s.split(" ")[2]]
#         y = s.split(" ")[3]
#     except:
#         return ""

#     return f'{d}-{m}-{y}'

# finaldata1["published"] = finaldata1["published"].apply(convert_date)

finaldata1['published'] = pd.to_datetime(
    finaldata1['published'], errors="coerce", dayfirst=True)
# Out:
# C:\Users\flavi\AppData\Local\Temp\ipykernel_36880\335718041.py:328: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   finaldata = pd.concat([finaldata, DRPipeline_result], axis=0)
# C:\Users\flavi\AppData\Local\Temp\ipykernel_36880\335718041.py:329: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   finaldata = pd.concat([finaldata, DROutros_result], axis=0)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [22], line 330
#     328 finaldata = pd.concat([finaldata, DRPipeline_result], axis=0)
#     329 finaldata = pd.concat([finaldata, DROutros_result], axis=0)
# ...

# %%
finaldata1[['title', 'kw', 'published', 'link']].to_excel(
    './exported/DR.xlsx')
