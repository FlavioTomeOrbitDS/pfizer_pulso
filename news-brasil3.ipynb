# %%
import requests
import pandas as pd
import requests
import time
import pandas as pd
import pymysql
from sqlalchemy import create_engine




df=pd.DataFrame()

DRATTR=["amiloidose","amiloidose","Vyndaqel","Vyndamax","Onpattro","patisirana","Tegsedi","inotersena","vutrisirana","PAF Polineuropatia Amiloidótica Familiar",
        "polineuropatia amiloidótica familiar","amiloidose cardíaca","ATTR","insuficiência cardíaca","ICFEp","QSART","Sudoscan",
        "Protocolo Insuficiência Cardíaca","wATTR","hATTR","síndrome túnel do carpo","Amiloidose associada à transtirretina",
        "Hipertrofia ventricular","Cardiomiopatia ","ATTR-CM","ATTR-PN","Cardiomiopatia amiloide","Cardiomiopatia amiloidótica por transtirretina",
        "CAF Cardiomiopatia Amiloidotica Familiar","Cardiomiopatia amiloide familiar","ATTRwt","ATTRh","ATTRm","ATTRv","Val30Met","Val50Met","V30M",
        "V50M","Val122Ile","Val142Ile","V122I","V142I","Cardiomiopatia restritiva","Fração de ejeção preservada","ATTR selvagem","ATTR hereditária",
        "Mutações TTR","Acoramidis","AG-10","Estabilizador TTR","Silenciador gênico TTR","ABPAR","Sequenciamento TTR","Teste genético ATTR",
        "sintomas e sinais PAF","sintomas e sinas ATTR-CM","doença hereditária"]

for i in DRATTR:
    #EXTRAIR METADADOS NOTICIAS 
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q":i,"lang":"pt","countries":"BR"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
            }
        
        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers, params=querystring).json()

        
        if response['articles']!=[]:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)
            
        else:
            df2=pd.DataFrame()
            df2[["id","title","link","published","sub_articles","source"]] = pd.DataFrame([["", "", "","","",""]])
            
            
        df2.insert(0,'company', i)
        df=pd.concat([df,df2], ignore_index=True, sort=False)
    
    
        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
            }
    except:
        pass

DRATTR_result=df
DRATTR_result=df
DRATTR_result=DRATTR_result.rename(columns={'company':'kw'})
DRATTR_result['categoria'] = 'ATTR'



df=pd.DataFrame()

DREndocrineCare = ["somatropina","hormônio GH","GH longa duração","Prader Willi","Síndrome Turner","BEI baixa estatura","Baixa Estatura Idiopática",
                   "disturbio de crescimento crianças","DGH","Norditropin","Saizen","hormotrop","Omnitrope","endócrino-pediatra","Endoped","Crescimento infantil",
                   "Endocrinologia Pediátrica","Pediatria crescimento infantil","Hormônio do crescimento","Desenvolvimento infantil altura crescimento",
                   "Curvas crescimento","Velocidade crescimento","PIG crescimento crianças","Pequeno para idade gestacional","Deficiência hormônio crescimento",
                   "Estirão crescimento","Segurança GH crescimento","Investigação baixa estatura crianças","Exoma crescimento","Cariótipo síndrome Turner",
                   "Estudo genético crianças baixa estatura","Fórmula de Tanner","pescoço alado síndrome Turner","IGF-1 crescimento infantil",
                   "IGFBP-3 crescimento infantil","exames genéticos baixa estatura","metilação DNA síndrome Prader-Willi",
                   "Hipotonia neonatal síndrome Prader-Willi"]

for i in DREndocrineCare:
    #EXTRAIR METADADOS NOTICIAS 
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q":i,"lang":"pt","countries":"BR"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
            }
        
        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers, params=querystring).json()

        
        if response['articles']!=[]:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)
            
        else:
            df2=pd.DataFrame()
            df2[["id","title","link","published","sub_articles","source"]] = pd.DataFrame([["", "", "","","",""]])
            
            
        df2.insert(0,'company', i)
        df=pd.concat([df,df2], ignore_index=True, sort=False)
    
    
        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
            }
    except:
        pass

DREndocrineCare_result=df
DREndocrineCare_result=df
DREndocrineCare_result=DREndocrineCare_result.rename(columns={'company':'kw'})
DREndocrineCare_result['categoria'] = 'EndocrineCare'






df=pd.DataFrame()

DRTransplante = ["imTOR","rapamicina","Rapamune","transplante renal","paciente transplantado","ABTO","transplante de orgãos",
                 "everolimo","Certican","Protocolo Imunossupressão rim","Imunossupressão rim","rim transplante","perda do rim","função renal",
                 "hemodiálise","lista de transplante rim ","PCDT de transplantes ","Associação Brasileira de Transplanstes de orgãos",
                 "Função Tardia do Rim","Micofenolato","Prednisona","Ciclosporina","Azatioprina","LAM doença pulmonar","Linfangioleiomiomatose",
                 "Enxerto rim","Infecções virais transplante","proteinúria transplante","rejeiçao do órgão transplante","Poliomavírus","CMV",
                 "Citomegalovírus","Exame PCR","Nivel sanguineo do imunossupressor","Dosagem sanguínea do imunossupressor","BK vírus",
                 "filtração glomerular","protocolos clínicos e diretrizes terapêuticas transplante","Micofenolato de sodio"]

for i in DRTransplante:
    #EXTRAIR METADADOS NOTICIAS 
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q":i,"lang":"pt","countries":"BR"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
            }
        
        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers, params=querystring).json()

        
        if response['articles']!=[]:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)
            
        else:
            df2=pd.DataFrame()
            df2[["id","title","link","published","sub_articles","source"]] = pd.DataFrame([["", "", "","","",""]])
            
            
        df2.insert(0,'company', i)
        df=pd.concat([df,df2], ignore_index=True, sort=False)
    
    
        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
            }
    except:
        pass

DRTransplante_result=df
DRTransplante_result=df
DRTransplante_result=DRTransplante_result.rename(columns={'company':'kw'})
DRTransplante_result['categoria'] = 'Transplante'






df=pd.DataFrame()

DRHemofilia = ["Fator VIII hemofilia","Fator Recombinante hemofilia","Fator plasmático hemofilia","Hemofílico",
               "BenefiX","alfanonacogue","Xyntha","alfamoroctocogue","Elprolix","alfaeftrenonacogue","Rixubis","gamanonacogue","sangramento hemofilia"]

for i in DRHemofilia:
    #EXTRAIR METADADOS NOTICIAS 
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q":i,"lang":"pt","countries":"BR"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
            }
        
        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers, params=querystring).json()

        
        if response['articles']!=[]:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)
            
        else:
            df2=pd.DataFrame()
            df2[["id","title","link","published","sub_articles","source"]] = pd.DataFrame([["", "", "","","",""]])
            
            
        df2.insert(0,'company', i)
        df=pd.concat([df,df2], ignore_index=True, sort=False)
    
    
        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
            }
    except:
        pass

DRHemofilia_result=df
DRHemofilia_result=df
DRHemofilia_result=DRHemofilia_result.rename(columns={'company':'kw'})
DRHemofilia_result['categoria'] = 'Hemofilia'






df=pd.DataFrame()

DRPipeline = ["terapia gênica","Exondys 51","eteplirsen","Vyondys","golodirsen","Vyondys 53","Amondys 45","casimersen",
              "zolgensma","onasemnogeno abeparvoveque","Luxturna","voretigene neparvoveque","Spinraza","nusinersena","Soliris","eculizumabe",
              "somatrogon","Duchenne","Doenças raras","Teste genético"]

for i in DRPipeline:
    #EXTRAIR METADADOS NOTICIAS 
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q":i,"lang":"pt","countries":"BR"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
            }
        
        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers, params=querystring).json()

        
        if response['articles']!=[]:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)
            
        else:
            df2=pd.DataFrame()
            df2[["id","title","link","published","sub_articles","source"]] = pd.DataFrame([["", "", "","","",""]])
            
            
        df2.insert(0,'company', i)
        df=pd.concat([df,df2], ignore_index=True, sort=False)
    
    
        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
            }
    except:
        pass

DRPipeline_result=df
DRPipeline_result=df
DRPipeline_result=DRPipeline_result.rename(columns={'company':'kw'})
DRPipeline_result['categoria'] = 'Terapia Gênica'






df=pd.DataFrame()

DROutros = ["Congresso Brasileiro Pediátrico de Endocrinologia e Metabologia",
            "Congresso Brasileiro de Neurologia","Congresso Brasileiro de Cardiologia","Congresso Brasileiro de Neurologia",
            "Congresso Brasileiro de Cardiologia","Congresso Brasileiro de Genética Médica","Congresso Brasileiro de Medicina Nuclear",
            "Departamento de Insuficiência Cardíaca","sociedade de cardiologia do estado de são paulo",
            "Congresso Brasileiro de Endocrinologia e Metabologia","Congresso Paulista de Endocrinologia e Metabologia",
            "Congresso Europeu de Transplanstes ","Congresso Brasileiro de Transplantes","Associação Brasileira de Transplante de Órgãos",
            "Congresso Brasileiro de Transplanstes de Orgãos","Congresso Mineiro de Transplantes"]

for i in DROutros:
    #EXTRAIR METADADOS NOTICIAS 
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q":i,"lang":"pt","countries":"BR"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
            }
        
        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers, params=querystring).json()

        
        if response['articles']!=[]:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)
            
        else:
            df2=pd.DataFrame()
            df2[["id","title","link","published","sub_articles","source"]] = pd.DataFrame([["", "", "","","",""]])
            
            
        df2.insert(0,'company', i)
        df=pd.concat([df,df2], ignore_index=True, sort=False)
    
    
        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
            }
    except:
        pass

DROutros_result=df
DROutros_result=df
DROutros_result=DROutros_result.rename(columns={'company':'kw'})
DROutros_result['categoria'] = 'Outros'



df=pd.DataFrame()

Vacinas=["CRIE vacina","Campanha de vacinação -cachorros -cachorro -cães -cão -PET","Doença pneumocócica vacina","Doença meningocócica vacina","Doença meningocócica vacina",
         "Covid vacina","VPC13","Pneumonia pneumocócica","Vacina pneumonia","Vacina meningite ","Onde vacinar ",
         "Encaminhamento do paciente de risco vacinação","CTAI vacinação","Conasems vacinação","Conass vacinação","Ministério da saúde vacinação",
         "Clínica de vacinação Nimenrix ","meningite meningocócica vacina","ACWY vacina","Meningite C vacina","Meningite B vacina",
         "Pentavalente  vacina","Streptococcus pneumoniae vacina","PAC vacina","Pneumonia bacteriana vacina","Otite Média Aguda vacina",
         "OMA vacina","pneumococo vacina","Sorotipo vacina","Sorogrupo vacina","Meningite Bacteriana vacina","Vacina conjugada vacina",
         "Vacina pollissacarídica vacina","Colonização nasofaríngea vacina","S. pneumonae vacina","Cepa pneumocócica vacina",
         "Marco Aurélio Safadi vacinação","Margareth Dalcomo vacinação","Angelica Rodrigues vacinação","Renato Kfouri vacinação",
         "Isabella Ballalai vacina","Rosana Richtmann vacina","SBIm vacina","Jornada de imunização vacina","Situação epidemiológica vacina",
         "Juarez Cunha vacina","Melissa Palmieri vacina","Monica Levi vacina","Clovis Arns vacina","Mauro Gomes vacina","Eitan Berezin vacina",
         "Ana Paula Burian vacina","Gecilmara Salviato vacina","Helena Sato vacina","Tania Petraglia vacina","encaminhamento do paciente de risco",
         "vacina RNA Comirnaty","vacina viva Nimenrix","vacina atenuada Nimenrix","vacina inativada Menveo","VPC15 vacina",
         "Pneumo 15 vacina","VPC10 vacina","Pneumo 10 vacina","VPC20 vacina","Pneumo 20 vacina","Pneumo 13 vacina",
         "resistência antimicrobiana vacina","VPP23 vacina","Pneumo 23 vacina"]

for i in Vacinas:
    #EXTRAIR METADADOS NOTICIAS 
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q":i,"lang":"pt","countries":"BR"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
            }
        
        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers, params=querystring).json()

        
        if response['articles']!=[]:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)
            
        else:
            df2=pd.DataFrame()
            df2[["id","title","link","published","sub_articles","source"]] = pd.DataFrame([["", "", "","","",""]])
            
            
        df2.insert(0,'company', i)
        df=pd.concat([df,df2], ignore_index=True, sort=False)
    
    
        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
            }
    except:
        pass

Vacinas_result=df
Vacinas_result=Vacinas_result.rename(columns={'company':'kw'})
Vacinas_result['categoria'] = 'Vacinas'





df=pd.DataFrame()

Hospitalar=["Gram-negativo","Analgesia multimodal","Dor Pós Operatória","Analgesia cirúrgica","Analgesia cirúrgica","Sem Opioides",
            "Poupar Opioide","AINE","COX2","Rápida Recuperação","Protocolo ERAS","Infecção bacteriana","Infecção fúngica","Anemia",
            "Anemia Ferropriva","Deficiência de ferro","Fadiga anemia","Cansaço anemia","Hemoglobina anemia","Hemograma anemia",
            "Resistência Bacteriana","Pseudomonas","KPC bacteria","Klebsiella","Sepse","Candidíase invasiva","Candidemia",
            "Candidemia na Pediatria","Pneumonia Adquirida em comunidade","Pneumonia","Candidemia invasiva","Infecção de Pele",
            "Aspergilose","Resistência a antibióticos ","Aeruginosa ","Coli bacteria","Pneumoniae","Referencia Aspergilose",
            "Stewardship antibiótico","Bacteremia","Infecção fúngica invasiva"]

for i in Hospitalar:
    #EXTRAIR METADADOS NOTICIAS 
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q":i,"lang":"pt","countries":"BR"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
            }
        
        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers, params=querystring).json()

        
        if response['articles']!=[]:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)
            
        else:
            df2=pd.DataFrame()
            df2[["id","title","link","published","sub_articles","source"]] = pd.DataFrame([["", "", "","","",""]])
            
            
        df2.insert(0,'company', i)
        df=pd.concat([df,df2], ignore_index=True, sort=False)
    
    
        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
            }
    except:
        pass
    
Hospitalar_result=df
Hospitalar_result=Hospitalar_result.rename(columns={'company':'kw'})
Hospitalar_result['categoria'] = 'Hospitalar'




df=pd.DataFrame()

SNC=["Depressão","Ansiedade","Antidepressivos ","Sindrome do pânico","Sindrome do pânico","TDM","Transtorno Depressivo Maior",
     "Depressivo sintomas","Ansiosos sintomas","Saúde Mental","Doença Mental","Desmame medicamento","Pristiq","Elifore",
     "Desvenlafaxina","Deller","Desve ","Lexapro","Brintellix","Transtorno Mental","Escitalopram","Venlafaxina","Paroxetina",
     "Duloxetina","Sertralina","Miratazapina","Fluoxetina","Vortioxetina","Fluvoxamina","Agomelatina","Bupropiona",
     "Tristeza depressão","Suicídio Depressão","Ansiedade Depressão","Depressão Sintomas","Farmacogenética Depressão",
     "Teste farmacogenético Depressão","comorbidade Depressão","Interação medicamentosa","Efeito colateral Antidepressivo",
     "Efeito adverso Antidepressivo","Obesidade Depressão","Burnout","Pandemia Depressão","Covid Depressão","TAG ansiedade"]

for i in SNC:
    #EXTRAIR METADADOS NOTICIAS 
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q":i,"lang":"pt","countries":"BR"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
            }
        
        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers, params=querystring).json()

        
        if response['articles']!=[]:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)
            
        else:
            df2=pd.DataFrame()
            df2[["id","title","link","published","sub_articles","source"]] = pd.DataFrame([["", "", "","","",""]])
            
            
        df2.insert(0,'company', i)
        df=pd.concat([df,df2], ignore_index=True, sort=False)
    
    
        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
            }
    except:
        pass

SNC_result=df
SNC_result=SNC_result.rename(columns={'company':'kw'})
SNC_result['categoria'] = 'SNC'




finaldata=pd.concat([Vacinas_result,Hospitalar_result], axis=0)
finaldata=pd.concat([finaldata,DRATTR_result], axis=0)
finaldata=pd.concat([finaldata,DREndocrineCare_result], axis=0)
finaldata=pd.concat([finaldata,DRTransplante_result], axis=0)
finaldata=pd.concat([finaldata,DRHemofilia_result], axis=0)
finaldata=pd.concat([finaldata,DRPipeline_result], axis=0)
finaldata=pd.concat([finaldata,DROutros_result], axis=0)
finaldata=pd.concat([finaldata,SNC_result], axis=0)


finaldata=finaldata.rename(columns={'published_date':'published','_id':'id'})
finaldata1 = finaldata[['kw','id','title','link','published','categoria']]



###
# def convert_date(s):
#     month_dict = {'Jan':'01', 'Feb':'02', 'Mar':'03', 'Apr':'04', 'May':'05', 'Jun':'06',
#                   'Jul':'07', 'Aug':'08', 'Sep':'09', 'Oct':'10', 'Nov':'11', 'Dec':'12'}

#     try:
#         d = s.split(" ")[1]
#         m = month_dict[s.split(" ")[2]]
#         y = s.split(" ")[3]
#     except:
#         return ""

#     return f'{d}-{m}-{y}'

# finaldata1["published"] = finaldata1["published"].apply(convert_date)

import datetime
finaldata1['published'] = pd.to_datetime(finaldata1['published'], errors="coerce", dayfirst=True )


print('salvando no db')
#INSERT NO DB
import pandas as pd
import pandas as pd
import numpy as np
import pymysql
from sqlalchemy import create_engine

host1='pfizerdb.cqxct8aqwlso.us-east-2.rds.amazonaws.com'
port1='3306'
user1='pfizer'
passw1='P!zer2597!'
database1='pfizerdb'

mydb1 = create_engine('mysql+pymysql://' + user1 + ':' + passw1 + '@' + host1 + ':' + str(port1) + '/' + database1 , echo=False)
finaldata1.to_sql(name='google_news_brasil_v2', con=mydb1, if_exists = 'append', index=False)
finaldata1.to_sql(name='google_news_brasil_assunto_v2', con=mydb1, if_exists = 'append', index=False)
# Out:
# C:\Users\flavi\AppData\Local\Temp\ipykernel_42796\4030099416.py:534: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   finaldata1['published'] = pd.to_datetime(finaldata1['published'], errors="coerce", dayfirst=True )
# salvando no db
# 1941

# %%
from datetime import datetime, timedelta
import requests
import pandas as pd
import requests
import time
import pandas as pd
import pymysql
from sqlalchemy import create_engine

df = pd.DataFrame()

today = datetime.today()
yesterday = datetime.today() - timedelta(days=1)


#Incluído em Março de 2023
# DRDoencaFalciforme = [
#     "Anemia Falciforme",
#     "Doença Falciforme",
#     "Teste pezinho AND anemia",
#     "Hemoglobina SS(HbSS)",
#     "Hemácia em foice",
#     "Crise álgica",
#     "Crises vaso-oclusivas",
#     "Oxbryta",
#     "Voxelotor",
#     "Hidroxiureia",
#     "Adakveo",
#     "Crizanlizumabe"
# ]

DRDoencaFalciforme = [
    "Anemia Falciforme",
    "Doença Falciforme",
    "Teste pezinho AND anemia",
    "Hemoglobina SS(HbSS)",
    "Hemácia em foice",
    "Crise álgica",
    "Crises vaso-oclusivas",
    "Oxbryta",
    "Voxelotor",
    "Hidroxiureia",
    "Adakveo",
    "Crizanlizumabe"
]

for i in DRDoencaFalciforme:
    #EXTRAIR METADADOS NOTICIAS
    try:
        url = "https://api.newscatcherapi.com/v2/search"
        querystring = {"q": i, "lang": "EN",
                      "from": "one year ago"}

        headers = {
            'x-api-key': "BbJk1vWYhB6jK6BJAoR8NFXL-acL8pqF0jdIQbbxI9A"
        }

        #response = requests.request("GET", url, headers=headers, params=querystring)
        response = requests.get(url, headers=headers,
                                params=querystring).json()

        if response['articles'] != []:
            df2 = pd.DataFrame.from_dict(response['articles'])
        # create column 'company' in the first position (position, column name, value)

        else:
            df2 = pd.DataFrame()
            df2[["id", "title", "link", "published", "sub_articles",
                "source"]] = pd.DataFrame([["", "", "", "", "", ""]])

        df2.insert(0, 'company', i)
        df = pd.concat([df, df2], ignore_index=True, sort=False)

        #COLETAR TEXTO DA NOTICIA
        url = "https://extract-news.p.rapidapi.com/v0/article"
        headers = {
            'x-rapidapi-key': "88b5804da0mshaec086ad3147560p16ac64jsn608ec3c7f56c",
            'x-rapidapi-host': "google-news.p.rapidapi.com"
        }
    except:
        pass

DRDoencaFalciforme = df
DRDoencaFalciforme = df
DRDoencaFalciforme = DRDoencaFalciforme.rename(columns={'company': 'kw'})
DRDoencaFalciforme['categoria'] = 'Doença Falciforme'

finaldata = DRDoencaFalciforme
finaldata=finaldata.rename(columns={'published_date':'published','_id':'id'})
finaldata1 = finaldata[['kw','id','title','link','published','categoria']]
finaldata1['published'] = pd.to_datetime(
    finaldata1['published'], errors="coerce", dayfirst=True)
# Out:
# C:\Users\flavi\AppData\Local\Temp\ipykernel_27652\2637602318.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   finaldata1['published'] = pd.to_datetime(

# %%
finaldata1
# Out:
#                     kw                                id  \
# 0    Anemia Falciforme  1e4357c00edeb7ab95b8f92d5dc79b68
# 1    Anemia Falciforme  279aa9b9b6ba4af57c988ed376bb4c0e
# 2    Anemia Falciforme  c7b8f74487d45309e2ccf91bd960287b
# 3    Anemia Falciforme  f452356a8fb711bebb298e80da82a159
# 4    Anemia Falciforme  8d186c0b013af9ff032c85b54f6bf0e4
# ..                 ...                               ...
# 232     Crizanlizumabe  731d862e42762cd7beef77c139669f44
# 233     Crizanlizumabe  65469b9b2f114a3c26669b16f2e39839
# 234     Crizanlizumabe  a2551acf91515737072d96122c41e6bb
# 235     Crizanlizumabe  98520c47325a2c45911ee4f59b16f2da
# 236     Crizanlizumabe  e2d7058b048ff64e0880b3eaa5141a7c
#
#                                                  title  \
# 0    Children and sickle cell anemia, central sport...
# 1                                  Sickle Cell Disease
# 2    GBT Initiates Expanded Access Program for Voxe...
# 3    GBT Initiates Expanded Access Program for Voxe...
# 4    GBT Initiates Expanded Access Program for Voxe...
# ..                                                 ...
# 232     Meet Zurry the 13 year old Sickle Cell Warrior
# 233  Fulcrum's Clinical Hold Highlights Tough Road ...
# 234    Conversations Surrounding SCD Treatment Options
# 235  Exploring Emerging Therapies and Their Potenti...
# 236  Pfizer vaults into sickle cell market as GBT d...
#
#                                                   link           published  \
# 0    https://pledgetimes.com/children-and-sickle-ce... 2022-06-22 08:11:49
# 1    https://www.dshs.texas.gov/newborn-screening-p... 2023-01-03 06:15:00
# 2    https://www.globenewswire.com/news-release/202... 2022-07-14 00:00:00
# 3    https://www.biospace.com/article/releases/gbt-... 2022-07-14 13:57:12
# 4    https://www.efe.com/efe/usa/comunicados/gbt-in... 2022-07-14 12:00:00
# ..                                                 ...                 ...
# 232  https://ghettoradio.co.ke/meet-zurry-the-13-ye... 2022-10-25 03:09:41
# 233  https://www.biospace.com/article/fulcrum-s-cli... 2023-02-27 07:10:00
# 234  https://www.hcplive.com/view/conversations-sur... 2022-10-19 16:17:00
# 235  https://www.hcplive.com/view/exploring-emergin... 2022-10-26 20:36:00
# 236  https://pharmaphorum.com/news/pfizer-vaults-in... 2022-08-08 17:43:33
#
#              categoria
# 0    Doença Falciforme
# 1    Doença Falciforme
# 2    Doença Falciforme
# 3    Doença Falciforme
# 4    Doença Falciforme
# ..                 ...
# 232  Doença Falciforme
# 233  Doença Falciforme
# 234  Doença Falciforme
# 235  Doença Falciforme
# 236  Doença Falciforme
#
# [237 rows x 6 columns]

# %%
#INSERT NO DB
import pandas as pd
import pandas as pd
import numpy as np
import pymysql
from sqlalchemy import create_engine

host1 = 'pfizerdb.cqxct8aqwlso.us-east-2.rds.amazonaws.com'
port1 = '3306'
user1 = 'pfizer'
passw1 = 'P!zer2597!'
database1 = 'pfizerdb'

mydb1 = create_engine('mysql+pymysql://' + user1 + ':' + passw1 +
                      '@' + host1 + ':' + str(port1) + '/' + database1, echo=False)

finaldata1.to_sql(name='google_news_mundo_last', con=mydb1,
                  if_exists='append', index=False)
# Out:
# 237
